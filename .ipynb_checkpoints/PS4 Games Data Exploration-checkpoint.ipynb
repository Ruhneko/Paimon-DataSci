# %% [markdown]
# # PS4 GAMES DATA EXPLORATION

# %% [markdown]
# About:

# %% [markdown]
# # DATA SCRAPING
# <font color='red'>Valid for March 2021</font>

# %% [markdown]
# ### Import all necessary packages

# %% [markdown]
# request - used to request a web page
#
# AsyncHTMLSession - used to request dynamic pages that use java script when loadin
#
# pandas -  an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
#
# BeautifulSoup - a Python library for pulling data out of HTML and XML files.
#
# json - a lightweight data-interchange format.

# %%
import requests
from requests_html import AsyncHTMLSession
import pandas as pd
from bs4 import BeautifulSoup
import json

# %% [markdown]
# # PART 1: Data Collection

# %% [markdown]
# (PLS EDIT) The group will collect data from 3 sites namely ps-timetracker.com for our player data...

# %% [markdown]
# ## 1.1 Web Scraping ps-timetracker.com
#
# PS-Timetracker is website that details the top 100 games in a monthly categorical manner based primarly on the total number of hours played, additionally, the dataset also includes the total playerbase, as well as the span of an average session. The website includes both singleplayer-genre games and multiplayer-oriented games, and is regularly updated per month.

# %% [markdown]
# The first step is to request the page and load it onto BeautifulSoup

# %%
URL="https://ps-timetracker.com/statistic/"

# %% [markdown]
# We begin by searching for the required data. We will use January 2021 as the month of interest.

# %%
page=requests.get(URL + "2021-01")
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# The ps-timetracker data is located on a table with the class "table table-striped"

# %%
ps4_timetables=soup.find("table", {"class": "table table-striped"})

# %% [markdown]
# We will find all the rows and store them into an array

# %%
ps4_timetables=ps4_timetables.find_all('tr')

# %% [markdown]
# We will then select a random row and view the contents so that we can extract them

# %%
info_row=ps4_timetables[3].contents

# %%
print(info_row)

# %% [markdown]
# Each even index of the table contains the \n symbol. The data we are looking for are located on odd indexes.
#
# Index
#
# 1 = Rank, 3 = Chart Movement, 5 =  Game Title, 7 = Hours Played, 9 = Number of Players, 11 = Total Sesssions for the month, and 13 = Average time spent per Session

# %%
# Extract items of interest
Rank=info_row[1].text.strip()
Chart_movement=info_row[3].text.strip()
Title=info_row[5].text.strip()
Hours_Played=info_row[7].text.strip()
Players=info_row[9].text.strip()
Sessions=info_row[11].text.strip()
Avg_Session=info_row[13].text.strip()

print(Rank + " " + Title + " " + " " + Hours_Played + " " + Players + " " + Sessions + " " + Avg_Session)

# %% [markdown]
# We will then create a loop to view each row. The headers are stored on index 0 of the table so we will start at index 1.

# %%
info_start = 1
for i in range(info_start, len(ps4_timetables)-1):
    # Extract items of interest
    info_row = ps4_timetables[i].contents
    Rank=info_row[1].text.strip()
    Chart_movement=info_row[3].text.strip()
    Title=info_row[5].text.strip()
    Hours_Played=info_row[7].text.strip()
    Players=info_row[9].text.strip()
    Sessions=info_row[11].text.strip()
    Avg_Session=info_row[13].text.strip()
    print(Rank + " " + Title + " " + " " + Hours_Played + " " + Players + " " + Sessions + " " + Avg_Session)

# %% [markdown]
# ### Final Code 1.1
#
# We can see the the Top 100 were able to be  viewed. We will now create the final code which is a double loop. The first loop is for going through each month's page, the format is **"https:// ps-timetracker.com /statistic/YEAR-MONTH"**. The second loop is the same as the on above which collects each row of data.

# %%
ps4_times_json = []
info_start = 1
Year = "2021"
Months = ["01","02","03"]

for i in range(0, len(Months)):
    page=requests.get(URL + Year + "-" + Months[i])
    soup = BeautifulSoup(page.content, 'html.parser')
    ps4_timetables=soup.find("table", {"class": "table table-striped"})
    ps4_timetables=ps4_timetables.find_all('tr')
    
    for j in range(info_start, len(ps4_timetables)-1):
        # Extract items of interest
        info_row = ps4_timetables[j].contents
        Rank=info_row[1].text.strip()
        Chart_Movement=info_row[3].text.strip()
        Title=info_row[5].text.strip()
        Hours_Played=info_row[7].text.strip()
        Players=info_row[9].text.strip()
        Sessions=info_row[11].text.strip()
        Avg_Session=info_row[13].text.strip()

        ps4_times_json.append({
            "Year": Year,
            "Month": Months[i],
            "Rank": Rank,
            "Chart_Movement": Chart_Movement,
            "Title": Title,
            "Hours_Played": Hours_Played,
            "Players": Players,
            "Sessions": Sessions,
            "Avg_Session": Avg_Session
        })

# %% [markdown]
# We will save the collected data to a JSON File

# %%
with open('ps4-times.json', 'w') as json_file:
    json.dump(ps4_times_json, json_file)

# %% [markdown]
# Viewing the data using a pandas dataframe for verification

# %%
ps4_times_df = pd.json_normalize(ps4_times_json)
ps4_times_df

# %% [markdown]
# ## 1.2 Web Scraping gamepressure.com
#
# Gamepressure is a gaming news and media platform offering guides and walkthroughs on various consoles and gaming platforms. The games on the PS4 platform were scraped from this website. Aside from the title of the game, tags that define the game, its developer, publisher, mode, release date, game description, and ratings were collected.

# %% [markdown]
# ### 1.2.1 LINK COLLECTION
#
# The first step is to request the page and load it onto BeautifulSoup

# %%
URL="https://www.gamepressure.com/games/"

# %% [markdown]
# The game data are stored on diffent pages, we will first go to the ps4 game list page to collect all the links

# %%
page=requests.get(URL + "ps4" + "/")
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# The links are stored in a div with class "lista lista-gry"

# %%
ps4_game_links=soup.find("div", {"class": "lista lista-gry"})

# %% [markdown]
# We will extract each link, which is stored in an anchor with class pic-c", and place them in an array

# %%
ps4_game_links=ps4_game_links.find_all("a", {"class": "pic-c"},href=True)

# %% [markdown]
# A for loop to verify if all the links were collected

# %%
for i in range (0, len(ps4_game_links)):
    print(ps4_game_links[i]['href'])

# %% [markdown]
# ### Final Code 1.2.1 Link Collection
#
# The final code to collect all links is a double for loop. The outer loop is used to iterate through each page and the inner loop is used to store all the links

# %%
start_page = 1;
end_page = 21
ps4_links= []

for i in range (start_page, end_page):
    page=requests.get(URL + "ps4" + "/-" + str(i))
    soup = BeautifulSoup(page.content, 'html.parser')
    ps4_game_links=soup.find("div", {"class": "lista lista-gry"}) 
    ps4_game_links=ps4_game_links.find_all("a", {"class": "pic-c"},href=True) 
    
    for j in range (0, len(ps4_game_links)):
        ps4_links.append(ps4_game_links[j]['href'])

# %%
ps4_links[3]

# %% [markdown]
# ### 1.2.2 GAME DATA

# %% [markdown]
# We will now select the first link to look for the game data. We will use an AsyncHTMLSession because the ratings portion requires javascript

# %%
URL="https://www.gamepressure.com"

# %% [markdown]
# The amount of time it too for pages to render wasn't tracked, so the timeout was set to 0. However, this code may be modified to select a specific timeout to avoid a page connection failure which would freeze the code.

# %%
from requests_html import AsyncHTMLSession
session = AsyncHTMLSession()
r = await session.get(URL + ps4_links[0])
await r.html.arender(timeout=0) 
print(r.html.raw_html)

# %%
soup = BeautifulSoup(r.html.raw_html, 'html.parser')

# %% [markdown]
# The game data is stored in a section with class "article left"

# %%
game_info=soup.find("section", {"class": "article-left"})

# %% [markdown]
# The game title is store  on a span with id "game-title-cnt"

# %%
game_title = game_info.find("span", {"id": "game-title-cnt"})
print(game_title.text.strip())

# %% [markdown]
# The tags are stored in anchors within a paragraph with class "tagi"

# %%
tags_list = []
tags = game_info.find("p", {"class": "tagi"})
tags = tags.find_all("a")
for i in range(0, len(tags)):
    tags_list.append(tags[i].text.strip())

tags_list

# %% [markdown]
# The game developer name is stored in a div with id "game-developer-cnt"

# %%
game_developer = game_info.find("div", {"id": "game-developer-cnt"})
print("developer: " + game_developer.text.strip().replace("developer: ", ""))

# %% [markdown]
# The game publisher name is stored in a div with id "game-publisher-cnt"

# %%
game_publisher = game_info.find("div", {"id": "game-publisher-cnt"})
print("publisher: " + game_publisher.text.strip().replace("publisher: ", ""))

# %% [markdown]
# The game mode is stored in a div with class "S016-game-info"

# %%
game_mode = game_info.find("div", {"class": "S016-game-info"})
game_mode = game_mode.find_all("p")
print("Game mode: " + game_mode[3].text.strip().replace("Game mode: ", ""))

# %% [markdown]
# To get the release date we first enter a div with id "game-dates-cnt". We then find the paragraph with class "p2". Withing this pargraph there are three spans that contain the day,month,and year these spans have classes "s1,s2,3"

# %%
release_date = game_info.find("div", {"id": "game-dates-cnt"})
release_date = release_date.find("p", {"class": "p2"})
release_date_day = release_date.find("span", {"class": "s1"})
release_date_month = release_date.find("span", {"class": "s2"}) 
release_date_year = release_date.find("span", {"class": "s3"})

print("Release date: " + release_date_day.text.strip() + " " + release_date_month.text.strip() + " " + release_date_year.text.strip())

# %% [markdown]
# The game description content varies per page. We will just collect all the content and clean it later

# %%
game_description = game_info.find("div", {"id": "game-description-cnt"})
game_description = game_description.text.strip()
game_description

# %% [markdown]
# The game rating is stored in spans within a div with id "game-mis-cnt". The firt span (index 0) is the current score, the second span (index 1) is the expected score, both number are stored as the first object (index 0) within the spans.

# %%
game_rating = game_info.find("div", {"id": "game-misc-cnt"})
game_rating = game_rating.find_all("span")

current = game_rating[0].find_all("b")[0].text.strip()
expected = game_rating[1].find_all("b")[0].text.strip()

print("Current Score: " + current)
print("Expected Score: " + expected)

# %% [markdown]
# We will close the asynch session that we created

# %%
session.close()

# %% [markdown]
# ### Final Code 1.2.2 Game Data

# %% [markdown]
# The main loop is a single loop which implements all the subcodes above. The loop iterates over all the links and collects the data. It also saves the data into a json file after collection. The collection took 3-4 hours, there is no error checking or time out for the page requests so that may have played a part.

# %%
ps4_games_json = []
URL="https://www.gamepressure.com"

for i in range (0, len(ps4_links)):
    session = AsyncHTMLSession()
    r = await session.get(URL + ps4_links[i])
    await r.html.arender(timeout=0) 
    soup = BeautifulSoup(r.html.raw_html, 'html.parser')
    
    game_info = soup.find("section", {"class": "article-left"}) 
    
    if game_info is not None:
        game_title = game_info.find("span", {"id": "game-title-cnt"})
        if game_title is not None:
            game_title = game_title.text.strip()

        tags_list = []
        tags = game_info.find("p", {"class": "tagi"})
        tags = tags.find_all("a")
        if tags is not None:
            for j in range(0, len(tags)):
                tags_list.append(tags[j].text.strip())

        game_developer = game_info.find("div", {"id": "game-developer-cnt"})
        if game_developer is not None:
            game_developer = game_developer.text.strip().replace("developer: ", "")
 
        game_publisher = game_info.find("div", {"id": "game-publisher-cnt"})
        if game_publisher is not None:
            game_publisher = game_publisher.text.strip().replace("publisher: ", "")

        game_mode = game_info.find("div", {"class": "S016-game-info"})
        game_mode = game_mode.find_all("p")
        if(len(game_mode) >= 4):
            game_mode = game_mode[3].text.strip().replace("Game mode: ", "")
        else:
            game_mode = None

        release_date = game_info.find("div", {"id": "game-dates-cnt"})
        release_date = release_date.find("p", {"class": "p2"})
        release_date_day = None
        release_date_month = None
        release_date_year = None
        if release_date.find("span", {"class": "s1"}) is not None:
            release_date_day = release_date.find("span", {"class": "s1"}).text.strip()
        if release_date.find("span", {"class": "s2"}) is not None:
            release_date_month = release_date.find("span", {"class": "s2"}).text.strip()
        if release_date.find("span", {"class": "s3"}) is not None:
            release_date_year = release_date.find("span", {"class": "s3"}).text.strip()

        game_description = game_info.find("div", {"id": "game-description-cnt"})
        if game_description is not None:
            game_description = game_description.text.strip()
        else:
            game_description = None


        game_rating = game_info.find("div", {"id": "game-misc-cnt"})
        if game_rating is not  None:
            game_rating = game_rating.find_all("span")

            if game_rating is None:
                current = None
                expected = None
            elif(len(game_rating) == 2):
                current = game_rating[0].find_all("b")[0].text.strip()
                expected = game_rating[1].find_all("b")[0].text.strip()
            elif (len(game_rating) == 1):
                current = None
                expected = game_rating[0].find_all("b")[0].text.strip()


        ps4_games_json.append({
                "Title":  game_title,
                "Tags": tags_list,
                "Developer": game_developer,
                "Publisher": game_publisher,
                "Mode": game_mode,
                "Release_Date_Day": release_date_day,
                "Release_Date_Month": release_date_month,
                "Release_Date_Year": release_date_year,
                "Game_Description": game_description,
                "Expected_Rating": expected,
                "Current_Rating": current
        })

    await session.close()
    
with open('ps4-games.json', 'w') as json_file:
    json.dump(ps4_games_json, json_file)

# %% [markdown]
# We will view the data in a pandas dataframe for verification

# %%
ps4_times_df = pd.json_normalize(ps4_games_json)
ps4_times_df

# %% [markdown]
# ## 1.3 Web scraping VGchartz
#
# VGCharts is game coverage website that categorizes details of certain games into a database. Details include the platform, title, total shipped, sales from NA region, PAL region, Japan region, and other regions, as well as its total sales.

# %% [markdown]
# We will first create an array with keywords for the consoles

# %%
console = ["XOne", "PS4", "PC", "NS"]

# %% [markdown]
# We will search for the data using a randomly selected console. VGchartz is a database so the following filters were applied:
#
# (insert filters)

# %%
URL = "https://www.vgchartz.com/games/games.php?name=&keyword=&console=" + console[0] + "&region=All&developer=&publisher=&goty_year=&genre=&boxart=Both&banner=Both&ownership=Both&showmultiplat=No&results=15000&order=Sales&showtotalsales=0&showtotalsales=1&showpublisher=0&showvgchartzscore=0&shownasales=0&shownasales=1&showdeveloper=0&showcriticscore=0&showpalsales=0&showpalsales=1&showreleasedate=0&showuserscore=0&showjapansales=0&showjapansales=1&showlastupdate=0&showothersales=0&showothersales=1&showshipped=0&showshipped=1"

# %% [markdown]
# The VGChartz database is slow and is prone to server errors. We will set a timeout of 300 and check for status code 200/Success

# %%
status = 0
while(status!=200):
    try: 
        page = requests.get(URL, timeout=300)
        status = page.status_code
    except requests.exceptions.Timeout as err:
        status = 200
soup = BeautifulSoup(page.content, 'html.parser')
soup

# %% [markdown]
# The data is stored in a table, there is no ID so we will just get all table rows

# %%
sales_table = soup.find_all("tr")

# %% [markdown]
# The first 27 table rows contain random elements from the website, the sales data begins at row 28 and ends at rows-1

# %%
size = len(sales_table) - 1

# %%
sales_table = sales_table[27:size]

# %%
len(sales_table)

# %% [markdown]
# After extracting the rows, we will now select a random item to extract the sales data

# %%
item = sales_table[0]

# %% [markdown]
# We will find all the items in each row and store them in an array

# %%
item = item.find_all("td")

# %% [markdown]
# The data is stored from index 0-9, excluding index 1 becuase this is just the number of the game on the list of games and index 3 which is (PLEASE CHECK).
#
# Index 0 = game publisher, Index 2 = game title, Index 4 = total number of copies shipped, Index 5 is the total amount of sales in millions, Index 6-9 are specific sales in millions for North America, PAL, Japan, and Others.

# %%
sales_publisher = console[0]
sales_title = item[2].text.strip()
sales_total_shipped = item[4].text.strip()
sales_total_sales = item[5].text.strip()
sales_NA_sales = item[6].text.strip()
sales_PAL_sales = item[7].text.strip()
sales_Japan_sales = item[8].text.strip()
sales_Other_sales = item[9].text.strip()


print(sales_publisher + " " + sales_title + " " + sales_total_shipped + " " + 
      sales_total_sales + " " + sales_NA_sales + " " + sales_PAL_sales + " " +
     sales_Japan_sales + " " + sales_Other_sales)

# %% [markdown]
# ### Final Code 1.3

# %% [markdown]
# The main code is a double loop, the outer loop queries for 15,000 objects from each console and the inner loop collects the data. After collecting the data, it is stored in a json file

# %%
console = ["XOne", "PS4", "PC", "NS"]
ps4_sales_json = []

for i in range (0, len(console)):
    URL = "https://www.vgchartz.com/games/games.php?name=&keyword=&console=" + console[i] + "&region=All&developer=&publisher=&goty_year=&genre=&boxart=Both&banner=Both&ownership=Both&showmultiplat=No&results=15000&order=Sales&showtotalsales=0&showtotalsales=1&showpublisher=0&showvgchartzscore=0&shownasales=0&shownasales=1&showdeveloper=0&showcriticscore=0&showpalsales=0&showpalsales=1&showreleasedate=0&showuserscore=0&showjapansales=0&showjapansales=1&showlastupdate=0&showothersales=0&showothersales=1&showshipped=0&showshipped=1"
    status = 0
    while(status!=200):
        try: 
            page = requests.get(URL, timeout=300)
            status = page.status_code
        except requests.exceptions.Timeout as err:
            status = 200
    soup = BeautifulSoup(page.content, 'html.parser')
    sales_table = soup.find_all("tr")
    size = len(sales_table) - 1
    sales_table = sales_table[27:size]
    
    for j in range (0, len(sales_table)):
        item = sales_table[j]
        item = item.find_all("td")
        sales_publisher = console[i]
        sales_title = item[2].text.strip()
        sales_total_shipped = item[4].text.strip()
        sales_total_sales = item[5].text.strip()
        sales_NA_sales = item[6].text.strip()
        sales_PAL_sales = item[7].text.strip()
        sales_Japan_sales = item[8].text.strip()
        sales_Other_sales = item[9].text.strip()

        ps4_sales_json.append({
            
            "Publisher": sales_publisher,
            "Title": sales_title,
            "Total_Shipped": sales_total_shipped,
            "Total_Sales": sales_total_sales,
            "NA_Sales": sales_NA_sales,
            "PAL_Sales": sales_PAL_sales,
            "Japan_Sales": sales_Japan_sales,
            "Other_Sales": sales_Other_sales 
             
        })
        
with open('ps4-sales.json', 'w') as json_file:
    json.dump(ps4_sales_json, json_file)

# %% [markdown]
# ### After Checking Files

# %%
missing = ['https://www.gamepressure.com/games/black-desert-online/zf335d#ps4',
'https://www.gamepressure.com/games/brawlhalla/zf45a5#ps4',
'https://www.gamepressure.com/games/call-of-duty-black-ops-iiii/zf51ed#ps4',
'https://www.gamepressure.com/games/call-of-duty-black-ops-cold-war/z45a8f#ps4',
'https://www.gamepressure.com/games/call-of-duty-black-ops-iii/z03fb5#ps4',
'https://www.gamepressure.com/games/conan-exiles/z04624#ps4',
'https://www.gamepressure.com/games/demons-souls-remake/ze5be2', 
'https://www.gamepressure.com/games/destruction-allstars/z15be5',
'https://www.gamepressure.com/games/diablo-iii-reaper-of-souls-ultimate-evil-edition/z1391d#ps4',
'https://www.gamepressure.com/games/dying-light-the-following/z543f8#ps4',
'https://www.gamepressure.com/games/efootbal-pes-2021-season-update/z25c64',
'https://www.gamepressure.com/games/enter-the-gungeon/z13f5c#ps4',
'https://www.gamepressure.com/games/final-fantasy-xiv-a-realm-reborn/zd922#ps4',
'https://www.gamepressure.com/games/gran-turismo-sport/zd4522',
'https://www.gamepressure.com/games/hollow-knight/z14b7d#ps4',
'https://www.gamepressure.com/games/hunt-showdown/z03d4e#ps4',
'https://www.gamepressure.com/games/immortals-fenyx-rising/zf5820#ps4',
'https://www.gamepressure.com/games/madden-nfl-21/z55b86#ps4',
'https://www.gamepressure.com/games/maneater/zd53cb#ps4',
'https://www.gamepressure.com/games/spider-man/z04831',
'https://www.gamepressure.com/games/spider-man-miles-morales/z25be6#ps4',
'https://www.gamepressure.com/games/monster-hunter-world-iceborne/za579e#ps4',
'https://www.gamepressure.com/games/nba-2k20/z85847#ps4',
'https://www.gamepressure.com/games/outriders/z457d4#ps4',
'https://www.gamepressure.com/games/overwatch/z43ef6#ps4',
'https://www.gamepressure.com/games/paladins-champions-of-the-realm/zd43ea#ps4',
'https://www.gamepressure.com/games/persona-5-scramble-the-phantom-strikers/z75783#ps4',
'https://www.gamepressure.com/games/rise-of-the-tomb-raider/ze3d6a#ps4',
'https://www.gamepressure.com/games/rogue-company/z0591a#ps4',
'https://www.gamepressure.com/games/rust/z23807#ps4',
'https://www.gamepressure.com/games/the-elder-scrolls-v-skyrim-special-edition/z2481e#ps4',
'https://www.gamepressure.com/games/smite/z02de5#ps4',
'https://www.gamepressure.com/games/tom-clancys-rainbow-six-siege/z23d74#ps4',
'https://www.gamepressure.com/games/tom-clancys-ghost-recon-breakpoint/z7578c#ps4',
'https://www.gamepressure.com/games/uncharted-4-a-thiefs-end/ze3a7c',b
'https://www.gamepressure.com/games/warface/z4259d#ps4',
'https://www.gamepressure.com/games/we-were-here/ze4cbe#ps4',
'https://www.gamepressure.com/games/world-of-tanks-mercenaries/z229e2#ps4']

# %%
ps4_missing_games_json = []

for i in range (0, len(missing)):
    session = AsyncHTMLSession()
    r = await session.get(missing[i])
    await r.html.arender(timeout=0) 
    soup = BeautifulSoup(r.html.raw_html, 'html.parser')
    
    game_info = soup.find("section", {"class": "article-left"}) 
    
    if game_info is not None:
        game_title = game_info.find("span", {"id": "game-title-cnt"})
        if game_title is not None:
            game_title = game_title.text.strip()

        tags_list = []
        tags = game_info.find("p", {"class": "tagi"})
        tags = tags.find_all("a")
        if tags is not None:
            for j in range(0, len(tags)):
                tags_list.append(tags[j].text.strip())

        game_developer = game_info.find("span", {"id": "game-developer-cnt"})
        if game_developer is not None:
            game_developer = game_developer.text.strip().replace("developer: ", "")
 
        game_publisher = game_info.find("span", {"id": "game-publisher-cnt"})
        if game_publisher is not None:
            game_publisher = game_publisher.text.strip().replace("publisher: ", "")

        game_mode = game_info.find("div", {"id": "game-misc-cnt"})
        game_mode = game_mode.find_all("p")
        game_mode = game_mode[0].find("b")
        game_mode =game_mode.text.strip()

        release_date = game_info.find("div", {"id": "game-dates-cnt"})
        release_date = release_date.find("p", {"class": "p2"})
        release_date_day = None
        release_date_month = None
        release_date_year = None
        if release_date.find("span", {"class": "s1"}) is not None:
            release_date_day = release_date.find("span", {"class": "s1"}).text.strip()
        if release_date.find("span", {"class": "s2"}) is not None:
            release_date_month = release_date.find("span", {"class": "s2"}).text.strip()
        if release_date.find("span", {"class": "s3"}) is not None:
            release_date_year = release_date.find("span", {"class": "s3"}).text.strip()

        game_description = game_info.find("div", {"id": "game-description-cnt"})
        if game_description is not None:
            game_description = game_description.text.strip()
        else:
            game_description = None


        game_rating = game_info.find("div", {"id": "game-misc-cnt"})
       
        if game_rating is not  None:
            game_rating = game_rating.find_all("p")

            if game_rating is None:
                current = None
                expected = None
            elif(len(game_rating) == 3):
                current = game_rating[1].find_all("b")[0].text.strip()
                expected = game_rating[2].find_all("b")[0].text.strip()
            elif (len(game_rating) == 2):
                current = None
                expected = game_rating[1].find_all("b")[0].text.strip()


        ps4_missing_games_json.append({
                "Title":  game_title,
                "Tags": tags_list,
                "Developer": game_developer,
                "Publisher": game_publisher,
                "Mode": game_mode,
                "Release_Date_Day": release_date_day,
                "Release_Date_Month": release_date_month,
                "Release_Date_Year": release_date_year,
                "Game_Description": game_description,
                "Expected_Rating": expected,
                "Current_Rating": current
        })

    await session.close()
    
with open('ps4-games-missing.json', 'w') as json_file:
    json.dump(ps4_missing_games_json, json_file)

# %% [markdown]
# # PART 2: Data Preprocessing

# %%
import numpy as np
import pandas as pd
import json
import datetime
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
df_ps4_times = pd.read_json('Datasets/ps4-times.json')
df_ps4_games = pd.read_json('Datasets/ps4-games.json')
df_ps4_sales = pd.read_json('Datasets/ps4-sales.json')

# %%
df_ps4_games['Title']
# Out:
# 0                  Cyberpunk 2077
# 1              Horizon: Zero Dawn
# 2                       Days Gone
# 3      Assassin's Creed: Valhalla
# 4           Resident Evil Village
#                   ...
# 474       The King of Fighters XV
# 475                         Thief
# 476                Fishing Planet
# 477                    Watch Dogs
# 478                  Overcooked 2
# Name: Title, Length: 479, dtype: object

# %%
Title_cleaned = []
for index, row in df_ps4_times.iterrows():
    row['Title'] = row['Title'].lower()
    row['Title'] = row['Title'].replace('™','')
    row['Title'] = row['Title'].replace('®','')
    row['Title'] = row['Title'].replace(':','')
    row['Title'] = row['Title'].replace('–','')
    #print(row['Title'])
    Title_cleaned.append(row['Title'])
df_ps4_times['Title'] = Title_cleaned

# %%
Title_cleaned = []
for index, row in df_ps4_games.iterrows():
    row['Title'] = row['Title'].lower()
    row['Title'] = row['Title'].replace('™','')
    row['Title'] = row['Title'].replace('®','')
    row['Title'] = row['Title'].replace(':','')
    row['Title'] = row['Title'].replace('–','')
    #print(row['Title'])
    Title_cleaned.append(row['Title'])
df_ps4_games['Title'] = Title_cleaned

# %%
Title_cleaned = []
for index, row in df_ps4_sales.iterrows():
    row['Title'] = row['Title'].lower()
    row['Title'] = row['Title'].replace('™','')
    row['Title'] = row['Title'].replace('®','')
    row['Title'] = row['Title'].replace(':','')
    row['Title'] = row['Title'].replace('–','')
    row['Title'] = row['Title'].replace(' read the review','')
    #print(row['Title'])
    Title_cleaned.append(row['Title'])
df_ps4_sales['Title'] = Title_cleaned

# %%
df_ps4_sales = df_ps4_sales.replace("0.00m",np.NaN)
df_ps4_sales = df_ps4_sales.replace("N/A",np.NaN)
df_ps4_sales = df_ps4_sales.drop_duplicates()
df_ps4_drop_sales = df_ps4_sales[df_ps4_sales["Publisher"] == 'PS4']
df_ps4_drop_sales
# Out:
#      Publisher                              Title Total_Shipped Total_Sales  \
# 1510       PS4             marvel's spider-man           20.00m         NaN
# 1511       PS4                 grand theft auto v           NaN      19.39m
# 1512       PS4          uncharted 4 a thief's end        16.25m         NaN
# 1513       PS4           call of duty black ops 3           NaN      15.09m
# 1514       PS4           red dead redemption 2              NaN      13.94m
# ...        ...                                ...           ...         ...
# 3782       PS4       ys memories of celceta - kai           NaN         NaN
# 3783       PS4    yu-gi-oh! legacy of the duelist           NaN         NaN
# 3784       PS4                      yuppie psycho           NaN         NaN
# 3785       PS4             zombie army 4 dead war           NaN         NaN
# 3786       PS4  zombieland double tap - road trip           NaN         NaN
#
#      NA_Sales PAL_Sales Japan_Sales Other_Sales
# 1510      NaN       NaN         NaN         NaN
# 1511    6.06m     9.71m       0.60m       3.02m
# 1512      NaN       NaN         NaN         NaN
# 1513    6.18m     6.05m       0.41m       2.44m
# 1514    5.26m     6.21m       0.21m       2.26m
# ...       ...       ...         ...         ...
# 3782      NaN       NaN         NaN         NaN
# 3783      NaN       NaN         NaN         NaN
# 3784      NaN       NaN         NaN         NaN
# 3785      NaN       NaN         NaN         NaN
# 3786      NaN       NaN         NaN         NaN
#
# [2275 rows x 8 columns]

# %% [markdown]
# title problem -> lowercase everything, remove trademark/copyright logo, ":" sign, match all string in left to all string rights%
#
# # ™ ® : lowercase

# %% [markdown]
# for sales, aggregate into base on title, title get from top 100+ (df_ps4_times)
# final fantasy xiv$
#
#  row["Title"]$ = row["Title"]
#
# THISISASTRING........

# %% [markdown]
# times ... check how many times it appeared as top 100 most played
# if appeared more than once, get average monthly
# otherwise, copy paste
# counter-> feature -> "number of times appeared as top 100 (appearances)"

# %%
#for index, row in df_ps4_times.iterrows():
    #print(row['Title'])

# %%
#<300 samples
df_ps4_times_combined = df_ps4_times.sort_values(by=['Title'])
df_ps4_times_combined
# Out:
#      Year  Month  Rank Chart_Movement                 Title  Hours_Played  \
# 100  2021      2     1             +6          apex legends         94616
# 201  2021      3     2             -1          apex legends         92103
# 6    2021      1     7             +2          apex legends         51898
# 111  2021      2    12             +2  ark survival evolved         30138
# 13   2021      1    14             +4  ark survival evolved         28825
# ..    ...    ...   ...            ...                   ...           ...
# 183  2021      2    84            NEW          we were here          2857
# 191  2021      2    92            NEW        world of tanks          2563
# 296  2021      3    97             -5        world of tanks          2737
# 68   2021      1    69            -17  yakuza like a dragon          4333
# 263  2021      3    64            NEW  yakuza like a dragon          4522
#
#      Players  Sessions Avg_Session
# 100     3342     59571        1:36
# 201     3673     63635        1:27
# 6       2389     35661        1:28
# 111      879     10604        2:51
# 13       830     10105        2:52
# ..       ...       ...         ...
# 183     1582      2782        1:02
# 191      215      1749        1:28
# 296      244      2098        1:19
# 68       157      1788        2:26
# 263      197      2175        2:05
#
# [300 rows x 9 columns]

# %%
Avg_Session_Seconds = []
for index, row in df_ps4_times_combined.iterrows():
    row['Avg_Session'] += ":00"
    h,m,s = row['Avg_Session'].split(':')
    row['Avg_Session'] = int(datetime.timedelta(hours=int(h),minutes=int(m),seconds=int(s)).total_seconds())
    Avg_Session_Seconds.append(row['Avg_Session'])

df_ps4_times_combined["Avg_Session_Seconds"] = Avg_Session_Seconds

# %%
df_ps4_times_combined
# Out:
#      Year  Month  Rank Chart_Movement                 Title  Hours_Played  \
# 100  2021      2     1             +6          apex legends         94616
# 201  2021      3     2             -1          apex legends         92103
# 6    2021      1     7             +2          apex legends         51898
# 111  2021      2    12             +2  ark survival evolved         30138
# 13   2021      1    14             +4  ark survival evolved         28825
# ..    ...    ...   ...            ...                   ...           ...
# 183  2021      2    84            NEW          we were here          2857
# 191  2021      2    92            NEW        world of tanks          2563
# 296  2021      3    97             -5        world of tanks          2737
# 68   2021      1    69            -17  yakuza like a dragon          4333
# 263  2021      3    64            NEW  yakuza like a dragon          4522
#
#      Players  Sessions Avg_Session  Avg_Session_Seconds
# 100     3342     59571        1:36                 5760
# 201     3673     63635        1:27                 5220
# 6       2389     35661        1:28                 5280
# 111      879     10604        2:51                10260
# 13       830     10105        2:52                10320
# ..       ...       ...         ...                  ...
# 183     1582      2782        1:02                 3720
# 191      215      1749        1:28                 5280
# 296      244      2098        1:19                 4740
# 68       157      1788        2:26                 8760
# 263      197      2175        2:05                 7500
#
# [300 rows x 10 columns]

# %%
df_ps4_times_average = df_ps4_times_combined.groupby('Title').agg(
    # Get max of the duration column for each group
    Hours_Played=('Hours_Played', 'mean'),
    Players=('Players', 'mean'),
    Sessions=('Sessions', 'mean'),  
    Avg_Session_Seconds=('Avg_Session_Seconds', 'mean'),  
    Count=('Title','count')
)

df_ps4_times_average
# Out:
#                                       Hours_Played      Players      Sessions  \
# Title
# apex legends                          79539.000000  3134.666667  52955.666667
# ark survival evolved                  29608.333333   854.333333  10634.666667
# assassin's creed odyssey               6360.000000   424.666667   3168.000000
# assassin's creed origins               3421.000000   281.000000   1777.000000
# assassin's creed the ezio collection   3253.000000   174.000000   1474.000000
# ...                                            ...          ...           ...
# warframe                               5736.666667   315.333333   3394.333333
# watch dogs legion                      4527.666667   701.000000   3218.000000
# we were here                           2857.000000  1582.000000   2782.000000
# world of tanks                         2650.000000   229.500000   1923.500000
# yakuza like a dragon                   4427.500000   177.000000   1981.500000
#
#                                       Avg_Session_Seconds  Count
# Title
# apex legends                                         5420      3
# ark survival evolved                                10080      3
# assassin's creed odyssey                             7260      3
# assassin's creed origins                             6960      3
# assassin's creed the ezio collection                 7980      1
# ...                                                   ...    ...
# warframe                                             6120      3
# watch dogs legion                                    5480      3
# we were here                                         3720      1
# world of tanks                                       5010      2
# yakuza like a dragon                                 8130      2
#
# [122 rows x 5 columns]

# %%
#for index, row in df_ps4_times_average.iterrows():
    #print(row.name)

# %%
df_ps4_combined = df_ps4_times_average.merge(df_ps4_games, on='Title', how='left')

# %%
df_ps4_combined
# Out:
#                                     Title  Hours_Played      Players  \
# 0                            apex legends  79539.000000  3134.666667
# 1                    ark survival evolved  29608.333333   854.333333
# 2                assassin's creed odyssey   6360.000000   424.666667
# 3                assassin's creed origins   3421.000000   281.000000
# 4    assassin's creed the ezio collection   3253.000000   174.000000
# ..                                    ...           ...          ...
# 117                              warframe   5736.666667   315.333333
# 118                     watch dogs legion   4527.666667   701.000000
# 119                          we were here   2857.000000  1582.000000
# 120                        world of tanks   2650.000000   229.500000
# 121                  yakuza like a dragon   4427.500000   177.000000
#
#          Sessions  Avg_Session_Seconds  Count  \
# 0    52955.666667                 5420      3
# 1    10634.666667                10080      3
# 2     3168.000000                 7260      3
# 3     1777.000000                 6960      3
# 4     1474.000000                 7980      1
# ..            ...                  ...    ...
# 117   3394.333333                 6120      3
# 118   3218.000000                 5480      3
# 119   2782.000000                 3720      1
# 120   1923.500000                 5010      2
# 121   1981.500000                 8130      2
#
#                                                   Tags              Developer  \
# 0    [Action, FPP, science fiction, play for free, ...  Respawn Entertainment
# 1    [Action, FPP, dinosaurs, sandbox, RPG elements...        Studio Wildcard
# 2    [RPG, TPP, Stealth, sandbox, Ancient history, ...                Ubisoft
# 3    [Action, TPP, science fiction, Stealth, sandbo...                Ubisoft
# 4    [Action, TPP, science fiction, Stealth, packag...                Ubisoft
# ..                                                 ...                    ...
# 117  [Action, TPP, science fiction, play for free, ...       Digital Extremes
# 118  [Action, TPP, cyberpunk, science fiction, Stea...                Ubisoft
# 119                                                NaN                    NaN
# 120                                                NaN                    NaN
# 121  [RPG, TPP, turn-based, Gangster, Japan, jRPG, ...   Ryu ga Gotoku Studio
#
#                 Publisher                        Mode  Release_Date_Day  \
# 0    Electronic Arts Inc.                 multiplayer               4.0
# 1         Studio Wildcard        single / multiplayer              29.0
# 2                 Ubisoft               single player               5.0
# 3                 Ubisoft               single player              27.0
# 4                 Ubisoft               single player              15.0
# ..                    ...                         ...               ...
# 117      Digital Extremes  massive online multiplayer              15.0
# 118               Ubisoft        single / multiplayer              29.0
# 119                   NaN                         NaN               NaN
# 120                   NaN                         NaN               NaN
# 121                  SEGA               single player              10.0
#
#     Release_Date_Month Release_Date_Year  \
# 0             February              2019
# 1               August              2017
# 2              October              2018
# 3              October              2017
# 4             November              2016
# ..                 ...               ...
# 117           November              2013
# 118            October              2020
# 119                NaN               NaN
# 120                NaN               NaN
# 121           November              2020
#
#                                       Game_Description  Expected_Rating  \
# 0    Apex Legends is a free-to-play online FPP shoo...              4.1
# 1    ARK: Survival Evolved is a sandbox survival si...              8.6
# 2    Assassin's Creed Odyssey is the eleventh large...              7.3
# 3    Ubisoft bases its operations on both new and t...              8.3
# 4    Assassin's Creed: The Ezio Collection for PS4 ...              8.8
# ..                                                 ...              ...
# 117  Warframe is a cooperative science-fiction shoo...              7.6
# 118  Watch Dogs Legion is an action game with an op...              4.4
# 119                                                NaN              NaN
# 120                                                NaN              NaN
# 121  Yakuza: Like a Dragon is the next installment ...              6.6
#
#      Current_Rating
# 0               NaN
# 1             5.400
# 2             7.165
# 3             8.250
# 4             6.950
# ..              ...
# 117           6.700
# 118           6.940
# 119             NaN
# 120             NaN
# 121           6.400
#
# [122 rows x 16 columns]

# %%
df_ps4_combined_sales = df_ps4_combined.merge(df_ps4_drop_sales, on='Title', how='left')

# %% [markdown]
# combined <--> games =
# loop kukunin isang row ni combined (get the title[1..n])
# if title exists in games, get

# %% [markdown]
# combined <--> sales =

# %%
df_ps4_combined_sales
# Out:
#                                     Title  Hours_Played      Players  \
# 0                            apex legends  79539.000000  3134.666667
# 1                    ark survival evolved  29608.333333   854.333333
# 2                assassin's creed odyssey   6360.000000   424.666667
# 3                assassin's creed origins   3421.000000   281.000000
# 4    assassin's creed the ezio collection   3253.000000   174.000000
# ..                                    ...           ...          ...
# 117                              warframe   5736.666667   315.333333
# 118                     watch dogs legion   4527.666667   701.000000
# 119                          we were here   2857.000000  1582.000000
# 120                        world of tanks   2650.000000   229.500000
# 121                  yakuza like a dragon   4427.500000   177.000000
#
#          Sessions  Avg_Session_Seconds  Count  \
# 0    52955.666667                 5420      3
# 1    10634.666667                10080      3
# 2     3168.000000                 7260      3
# 3     1777.000000                 6960      3
# 4     1474.000000                 7980      1
# ..            ...                  ...    ...
# 117   3394.333333                 6120      3
# 118   3218.000000                 5480      3
# 119   2782.000000                 3720      1
# 120   1923.500000                 5010      2
# 121   1981.500000                 8130      2
#
#                                                   Tags              Developer  \
# 0    [Action, FPP, science fiction, play for free, ...  Respawn Entertainment
# 1    [Action, FPP, dinosaurs, sandbox, RPG elements...        Studio Wildcard
# 2    [RPG, TPP, Stealth, sandbox, Ancient history, ...                Ubisoft
# 3    [Action, TPP, science fiction, Stealth, sandbo...                Ubisoft
# 4    [Action, TPP, science fiction, Stealth, packag...                Ubisoft
# ..                                                 ...                    ...
# 117  [Action, TPP, science fiction, play for free, ...       Digital Extremes
# 118  [Action, TPP, cyberpunk, science fiction, Stea...                Ubisoft
# 119                                                NaN                    NaN
# 120                                                NaN                    NaN
# 121  [RPG, TPP, turn-based, Gangster, Japan, jRPG, ...   Ryu ga Gotoku Studio
#
#               Publisher_x                        Mode  ...  \
# 0    Electronic Arts Inc.                 multiplayer  ...
# 1         Studio Wildcard        single / multiplayer  ...
# 2                 Ubisoft               single player  ...
# 3                 Ubisoft               single player  ...
# 4                 Ubisoft               single player  ...
# ..                    ...                         ...  ...
# 117      Digital Extremes  massive online multiplayer  ...
# 118               Ubisoft        single / multiplayer  ...
# 119                   NaN                         NaN  ...
# 120                   NaN                         NaN  ...
# 121                  SEGA               single player  ...
#
#                                       Game_Description Expected_Rating  \
# 0    Apex Legends is a free-to-play online FPP shoo...             4.1
# 1    ARK: Survival Evolved is a sandbox survival si...             8.6
# 2    Assassin's Creed Odyssey is the eleventh large...             7.3
# 3    Ubisoft bases its operations on both new and t...             8.3
# 4    Assassin's Creed: The Ezio Collection for PS4 ...             8.8
# ..                                                 ...             ...
# 117  Warframe is a cooperative science-fiction shoo...             7.6
# 118  Watch Dogs Legion is an action game with an op...             4.4
# 119                                                NaN             NaN
# 120                                                NaN             NaN
# 121  Yakuza: Like a Dragon is the next installment ...             6.6
#
#     Current_Rating Publisher_y  Total_Shipped  Total_Sales NA_Sales PAL_Sales  \
# 0              NaN         PS4            NaN          NaN      NaN       NaN
# 1            5.400         PS4          1.00m          NaN      NaN       NaN
# 2            7.165         PS4            NaN        3.18m    1.18m     1.40m
# 3            8.250         PS4            NaN        4.06m    1.22m     2.11m
# 4            6.950         PS4            NaN        0.79m    0.14m     0.52m
# ..             ...         ...            ...          ...      ...       ...
# 117          6.700         PS4            NaN          NaN      NaN       NaN
# 118          6.940         PS4            NaN          NaN      NaN       NaN
# 119            NaN         NaN            NaN          NaN      NaN       NaN
# 120            NaN         NaN            NaN          NaN      NaN       NaN
# 121          6.400         NaN            NaN          NaN      NaN       NaN
#
#     Japan_Sales Other_Sales
# 0           NaN         NaN
# 1           NaN         NaN
# 2         0.09m       0.51m
# 3         0.11m       0.63m
# 4         0.02m       0.12m
# ..          ...         ...
# 117         NaN         NaN
# 118         NaN         NaN
# 119         NaN         NaN
# 120         NaN         NaN
# 121         NaN         NaN
#
# [122 rows x 23 columns]

# %%
df1 = df_ps4_combined_sales[df_ps4_combined_sales["Tags"].isna()]

# %% [markdown]
# pls drop share play (not a game, recording software for ps4)

# %%
df1
# Out:
#                                                  Title  Hours_Played  \
# 9                                         black desert   2985.000000
# 12                                          brawlhalla   6165.333333
# 13                            call of duty black ops 4   3397.000000
# 14                     call of duty black ops cold war  84386.000000
# 15                          call of duty black ops iii   5060.000000
# 18                                        conan exiles   2899.000000
# 28                                       demon's souls   4493.666667
# 30                                destruction allstars   3724.000000
# 32   diablo iii reaper of souls  ultimate evil edition   2593.500000
# 35         dying light the following  enhanced edition   2756.000000
# 37                    efootball pes 2021 season update   3211.666667
# 38                                   enter the gungeon   4683.000000
# 48                                   final fantasy xiv   9021.333333
# 55                                   gran turismosport   4855.000000
# 60                                       hollow knight   3972.666667
# 62                                       hunt showdown   3924.500000
# 63                             immortals fenyx rising    5469.666667
# 65                                       madden nfl 21   3190.666667
# 66                                            maneater   3866.000000
# 68                                 marvel's spider-man   4976.000000
# 69                   marvel's spider-man miles morales   6605.333333
# 72                       monster hunter world iceborne   7430.333333
# 74                                            nba 2k20   5741.333333
# 80                                    outriders - demo   3103.500000
# 81                           overwatch origins edition  20335.333333
# 82                                            paladins   2452.000000
# 85                                  persona 5 strikers   6766.000000
# 89                             rise of the tomb raider   3151.000000
# 91                                       rogue company   4278.666667
# 92                                           rust beta   6620.000000
# 95                                          share play   3946.333333
# 96                                              skyrim   3899.666667
# 97                                               smite   5215.000000
# 109                     tom clancy's rainbow six siege  51109.333333
# 111                 tom clancys ghost recon breakpoint   4550.000000
# 112                           uncharted 4 a thiefs end   3046.333333
# 116                                            warface   2927.000000
# 119                                       we were here   2857.000000
# 120                                     world of tanks   2650.000000
#
#          Players      Sessions  Avg_Session_Seconds  Count Tags Developer  \
# 9     112.500000    986.500000                11040      2  NaN       NaN
# 12    849.666667   7013.666667                 3180      3  NaN       NaN
# 13    444.666667   2530.666667                 4860      3  NaN       NaN
# 14   4041.333333  54989.000000                 5560      3  NaN       NaN
# 15    980.666667   4687.666667                 3920      3  NaN       NaN
# 18    150.000000   1104.500000                 9420      2  NaN       NaN
# 28    356.333333   2984.000000                 5460      3  NaN       NaN
# 30   1393.000000   4972.000000                 2700      1  NaN       NaN
# 32    248.500000   1321.000000                 7110      2  NaN       NaN
# 35    253.000000   1479.000000                 6720      1  NaN       NaN
# 37    189.666667   2694.333333                 4320      3  NaN       NaN
# 38   1995.000000   5513.000000                 3060      1  NaN       NaN
# 48    188.666667   2547.000000                12880      3  NaN       NaN
# 55    633.000000   4281.333333                 4120      3  NaN       NaN
# 60    534.000000   2809.000000                 5100      3  NaN       NaN
# 62    156.500000   1646.500000                 8730      2  NaN       NaN
# 63    348.333333   2900.333333                 6700      3  NaN       NaN
# 65    253.666667   2594.333333                 4460      3  NaN       NaN
# 66    955.000000   3147.000000                 4440      1  NaN       NaN
# 68    750.000000   3667.333333                 4900      3  NaN       NaN
# 69    827.333333   4832.333333                 4920      3  NaN       NaN
# 72    527.000000   3388.333333                 7920      3  NaN       NaN
# 74    459.666667   3942.333333                 5280      3  NaN       NaN
# 80    917.000000   2136.000000                 5220      2  NaN       NaN
# 81   1286.666667  14717.333333                 5000      3  NaN       NaN
# 82    354.000000   2127.000000                 4200      1  NaN       NaN
# 85    338.500000   3311.000000                 7440      2  NaN       NaN
# 89    410.000000   1828.000000                 6240      1  NaN       NaN
# 91    704.666667   3704.666667                 4180      3  NaN       NaN
# 92    455.000000   3139.000000                 7620      1  NaN       NaN
# 95   2059.000000   7797.666667                 1860      3  NaN       NaN
# 96    380.333333   2070.000000                 6800      3  NaN       NaN
# 97    275.333333   3319.666667                 5680      3  NaN       NaN
# 109  2789.333333  35063.666667                 5300      3  NaN       NaN
# 111   422.000000   2167.500000                 7590      2  NaN       NaN
# 112   459.666667   2019.666667                 5440      3  NaN       NaN
# 116   249.000000   2290.000000                 4620      1  NaN       NaN
# 119  1582.000000   2782.000000                 3720      1  NaN       NaN
# 120   229.500000   1923.500000                 5010      2  NaN       NaN
#
#     Publisher_x Mode  ...  Game_Description Expected_Rating Current_Rating  \
# 9           NaN  NaN  ...               NaN             NaN            NaN
# 12          NaN  NaN  ...               NaN             NaN            NaN
# 13          NaN  NaN  ...               NaN             NaN            NaN
# 14          NaN  NaN  ...               NaN             NaN            NaN
# 15          NaN  NaN  ...               NaN             NaN            NaN
# 18          NaN  NaN  ...               NaN             NaN            NaN
# 28          NaN  NaN  ...               NaN             NaN            NaN
# 30          NaN  NaN  ...               NaN             NaN            NaN
# 32          NaN  NaN  ...               NaN             NaN            NaN
# 35          NaN  NaN  ...               NaN             NaN            NaN
# 37          NaN  NaN  ...               NaN             NaN            NaN
# 38          NaN  NaN  ...               NaN             NaN            NaN
# 48          NaN  NaN  ...               NaN             NaN            NaN
# 55          NaN  NaN  ...               NaN             NaN            NaN
# 60          NaN  NaN  ...               NaN             NaN            NaN
# 62          NaN  NaN  ...               NaN             NaN            NaN
# 63          NaN  NaN  ...               NaN             NaN            NaN
# 65          NaN  NaN  ...               NaN             NaN            NaN
# 66          NaN  NaN  ...               NaN             NaN            NaN
# 68          NaN  NaN  ...               NaN             NaN            NaN
# 69          NaN  NaN  ...               NaN             NaN            NaN
# 72          NaN  NaN  ...               NaN             NaN            NaN
# 74          NaN  NaN  ...               NaN             NaN            NaN
# 80          NaN  NaN  ...               NaN             NaN            NaN
# 81          NaN  NaN  ...               NaN             NaN            NaN
# 82          NaN  NaN  ...               NaN             NaN            NaN
# 85          NaN  NaN  ...               NaN             NaN            NaN
# 89          NaN  NaN  ...               NaN             NaN            NaN
# 91          NaN  NaN  ...               NaN             NaN            NaN
# 92          NaN  NaN  ...               NaN             NaN            NaN
# 95          NaN  NaN  ...               NaN             NaN            NaN
# 96          NaN  NaN  ...               NaN             NaN            NaN
# 97          NaN  NaN  ...               NaN             NaN            NaN
# 109         NaN  NaN  ...               NaN             NaN            NaN
# 111         NaN  NaN  ...               NaN             NaN            NaN
# 112         NaN  NaN  ...               NaN             NaN            NaN
# 116         NaN  NaN  ...               NaN             NaN            NaN
# 119         NaN  NaN  ...               NaN             NaN            NaN
# 120         NaN  NaN  ...               NaN             NaN            NaN
#
#     Publisher_y  Total_Shipped  Total_Sales NA_Sales PAL_Sales Japan_Sales  \
# 9           NaN            NaN          NaN      NaN       NaN         NaN
# 12          NaN            NaN          NaN      NaN       NaN         NaN
# 13          NaN            NaN          NaN      NaN       NaN         NaN
# 14          NaN            NaN          NaN      NaN       NaN         NaN
# 15          NaN            NaN          NaN      NaN       NaN         NaN
# 18          PS4            NaN        0.21m    0.05m     0.05m       0.09m
# 28          NaN            NaN          NaN      NaN       NaN         NaN
# 30          NaN            NaN          NaN      NaN       NaN         NaN
# 32          NaN            NaN          NaN      NaN       NaN         NaN
# 35          NaN            NaN          NaN      NaN       NaN         NaN
# 37          NaN            NaN          NaN      NaN       NaN         NaN
# 38          PS4            NaN          NaN      NaN       NaN         NaN
# 48          NaN            NaN          NaN      NaN       NaN         NaN
# 55          NaN            NaN          NaN      NaN       NaN         NaN
# 60          NaN            NaN          NaN      NaN       NaN         NaN
# 62          PS4            NaN          NaN      NaN       NaN         NaN
# 63          NaN            NaN          NaN      NaN       NaN         NaN
# 65          PS4            NaN          NaN      NaN       NaN         NaN
# 66          PS4            NaN          NaN      NaN       NaN         NaN
# 68          NaN            NaN          NaN      NaN       NaN         NaN
# 69          PS4            NaN          NaN      NaN       NaN         NaN
# 72          PS4            NaN          NaN      NaN       NaN         NaN
# 74          PS4            NaN          NaN      NaN       NaN         NaN
# 80          NaN            NaN          NaN      NaN       NaN         NaN
# 81          NaN            NaN          NaN      NaN       NaN         NaN
# 82          PS4            NaN          NaN      NaN       NaN         NaN
# 85          NaN            NaN          NaN      NaN       NaN         NaN
# 89          PS4            NaN        2.07m    0.61m     1.08m       0.05m
# 91          PS4            NaN          NaN      NaN       NaN         NaN
# 92          NaN            NaN          NaN      NaN       NaN         NaN
# 95          NaN            NaN          NaN      NaN       NaN         NaN
# 96          NaN            NaN          NaN      NaN       NaN         NaN
# 97          NaN            NaN          NaN      NaN       NaN         NaN
# 109         PS4            NaN        4.36m    1.29m     2.06m       0.36m
# 111         NaN            NaN          NaN      NaN       NaN         NaN
# 112         NaN            NaN          NaN      NaN       NaN         NaN
# 116         NaN            NaN          NaN      NaN       NaN         NaN
# 119         NaN            NaN          NaN      NaN       NaN         NaN
# 120         NaN            NaN          NaN      NaN       NaN         NaN
#
#     Other_Sales
# 9           NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 18        0.02m
# 28          NaN
# 30          NaN
# 32          NaN
# 35          NaN
# 37          NaN
# 38          NaN
# 48          NaN
# 55          NaN
# 60          NaN
# 62          NaN
# 63          NaN
# 65          NaN
# 66          NaN
# 68          NaN
# 69          NaN
# 72          NaN
# 74          NaN
# 80          NaN
# 81          NaN
# 82          NaN
# 85          NaN
# 89        0.32m
# 91          NaN
# 92          NaN
# 95          NaN
# 96          NaN
# 97          NaN
# 109       0.64m
# 111         NaN
# 112         NaN
# 116         NaN
# 119         NaN
# 120         NaN
#
# [39 rows x 23 columns]

# %% [markdown]
# ## What are the games on the PS4 top 100 most played games (hours played) list for the first quarter of 2021?

# %% [markdown]
# To achieve this, we must sort the list of games in descending order by 'Hours_Played'.

# %%
df_ps4_combined_sales = df_ps4_combined_sales.sort_values(by=['Hours_Played'], ascending=False)
df_ps4_combined_sales
# Out:
#                                                  Title  Hours_Played  \
# 51                                            fortnite  93548.333333
# 14                     call of duty black ops cold war  84386.000000
# 16                         call of duty modern warfare  80789.333333
# 0                                         apex legends  79539.000000
# 56                                  grand theft auto v  78739.333333
# ..                                                 ...           ...
# 120                                     world of tanks   2650.000000
# 32   diablo iii reaper of souls  ultimate evil edition   2593.500000
# 31                                detroit become human   2564.000000
# 36                                     ea sports ufc 3   2509.500000
# 82                                            paladins   2452.000000
#
#          Players      Sessions  Avg_Session_Seconds  Count  \
# 51   4857.000000  71134.333333                 4760      3
# 14   4041.333333  54989.000000                 5560      3
# 16   4774.666667  56655.666667                 5160      3
# 0    3134.666667  52955.666667                 5420      3
# 56   4935.666667  45556.000000                 6240      3
# ..           ...           ...                  ...    ...
# 120   229.500000   1923.500000                 5010      2
# 32    248.500000   1321.000000                 7110      2
# 31    387.000000   1440.000000                 6420      1
# 36    487.500000   2632.500000                 3480      2
# 82    354.000000   2127.000000                 4200      1
#
#                                                   Tags              Developer  \
# 51   [Action, zombie, sandbox, survival, co-op, MMO...             Epic Games
# 14                                                 NaN                    NaN
# 16   [Action, FPP, modern conflicts, FPS, network, ...          Infinity Ward
# 0    [Action, FPP, science fiction, play for free, ...  Respawn Entertainment
# 56   [Action, FPP, TPP, vehicles, Gangster, sandbox...         Rockstar Games
# ..                                                 ...                    ...
# 120                                                NaN                    NaN
# 32                                                 NaN                    NaN
# 31   [Adventure, TPP, cyberpunk, science fiction, a...          Quantic Dream
# 36   [Sports, MMA, for 2 people, splitscreen, EA Play]              EA Sports
# 82                                                 NaN                    NaN
#
#                         Publisher_x                  Mode  ...  \
# 51                       Epic Games  single / multiplayer  ...
# 14                              NaN                   NaN  ...
# 16              Activision Blizzard  single / multiplayer  ...
# 0              Electronic Arts Inc.           multiplayer  ...
# 56                   Rockstar Games         single player  ...
# ..                              ...                   ...  ...
# 120                             NaN                   NaN  ...
# 32                              NaN                   NaN  ...
# 31   Sony Interactive Entertainment         single player  ...
# 36             Electronic Arts Inc.  single / multiplayer  ...
# 82                              NaN                   NaN  ...
#
#                                       Game_Description Expected_Rating  \
# 51   Fortnite for PC, PS4 and XONE is a third-perso...             7.2
# 14                                                 NaN             NaN
# 16   Call of Duty: Modern Warfare is an FPS release...             4.6
# 0    Apex Legends is a free-to-play online FPP shoo...             4.1
# 56   Rockstar Games studio has a few acclaimed game...             7.8
# ..                                                 ...             ...
# 120                                                NaN             NaN
# 32                                                 NaN             NaN
# 31   Detroit: Become Human for PS4 is another adven...             9.1
# 36   As the title itself might suggest, EA Sports U...             7.3
# 82                                                 NaN             NaN
#
#     Current_Rating Publisher_y  Total_Shipped  Total_Sales NA_Sales PAL_Sales  \
# 51           1.900         PS4            NaN        0.89m    0.42m     0.32m
# 14             NaN         NaN            NaN          NaN      NaN       NaN
# 16           7.645         PS4            NaN          NaN      NaN       NaN
# 0              NaN         PS4            NaN          NaN      NaN       NaN
# 56           8.950         PS4            NaN       19.39m    6.06m     9.71m
# ..             ...         ...            ...          ...      ...       ...
# 120            NaN         NaN            NaN          NaN      NaN       NaN
# 32             NaN         NaN            NaN          NaN      NaN       NaN
# 31           7.305         NaN            NaN          NaN      NaN       NaN
# 36           5.400         PS4            NaN        0.97m    0.40m     0.41m
# 82             NaN         PS4            NaN          NaN      NaN       NaN
#
#     Japan_Sales Other_Sales
# 51          NaN       0.15m
# 14          NaN         NaN
# 16          NaN         NaN
# 0           NaN         NaN
# 56        0.60m       3.02m
# ..          ...         ...
# 120         NaN         NaN
# 32          NaN         NaN
# 31          NaN         NaN
# 36        0.01m       0.16m
# 82          NaN         NaN
#
# [122 rows x 23 columns]

# %% [markdown]
# We only need to acquire the 'Title' and 'Hours_Played' from the dataframe.

# %%
df_most_played = df_ps4_combined_sales[['Hours_Played', 'Title']]
df_most_played
# Out:
#      Hours_Played                                              Title
# 51   93548.333333                                           fortnite
# 14   84386.000000                    call of duty black ops cold war
# 16   80789.333333                        call of duty modern warfare
# 0    79539.000000                                       apex legends
# 56   78739.333333                                 grand theft auto v
# ..            ...                                                ...
# 120   2650.000000                                     world of tanks
# 32    2593.500000  diablo iii reaper of souls  ultimate evil edition
# 31    2564.000000                               detroit become human
# 36    2509.500000                                    ea sports ufc 3
# 82    2452.000000                                           paladins
#
# [122 rows x 2 columns]

# %% [markdown]
# Since we are acquiring only the top 100 games, we drop the indexes from the bottom 22 rows.

# %%
df_most_played.drop(df_most_played.tail(22).index, inplace=True)
df_most_played
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#     Hours_Played                             Title
# 51  93548.333333                          fortnite
# 14  84386.000000   call of duty black ops cold war
# 16  80789.333333       call of duty modern warfare
# 0   79539.000000                      apex legends
# 56  78739.333333                grand theft auto v
# ..           ...                               ...
# 37   3211.666667  efootball pes 2021 season update
# 65   3190.666667                     madden nfl 21
# 89   3151.000000           rise of the tomb raider
# 80   3103.500000                  outriders - demo
# 83   3079.000000                         persona 5
#
# [100 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# We first split the values in to y and x values for plotting.

# %%
x_values = df_most_played['Title']
y_values = df_most_played['Hours_Played']

# %%
y_values
# Out:
# 51    93548.333333
# 14    84386.000000
# 16    80789.333333
# 0     79539.000000
# 56    78739.333333
#           ...
# 37     3211.666667
# 65     3190.666667
# 89     3151.000000
# 80     3103.500000
# 83     3079.000000
# Name: Hours_Played, Length: 100, dtype: float64

# %%
x_values
# Out:
# 51                            fortnite
# 14     call of duty black ops cold war
# 16         call of duty modern warfare
# 0                         apex legends
# 56                  grand theft auto v
#                     ...
# 37    efootball pes 2021 season update
# 65                       madden nfl 21
# 89             rise of the tomb raider
# 80                    outriders - demo
# 83                           persona 5
# Name: Title, Length: 100, dtype: object

# %%
#get the index as column
#x_values_index = x_values
#x_values_index = df_most_played.drop(['Title', 'Hours_Played'], axis=1)
#x_values_index['index1'] = x_values_index.index
#x_values_index = x_values_index['index1']

# %% [markdown]
# We display the bar graph for the top 100 most played games.

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = x_values
y = y_values
ax.bar(x,y)
plt.xlabel('Title')
plt.ylabel('Hours Played')
plt.title('Top 100 Most Played Games')
plt.show()

# %% [markdown]
# From the bar graph seen above, there is an extreme downward trend based on the distribution displayed with only the first percentile having relatively much higher hours played compared to the rest of the games in top 100 most played list.
#
# This shows that there is a stark contrast between the top 10 when compared to the rest and the popularity that comes with the top 10 (or more) is much higher than the rest trailing behind.

# %% [markdown]
# ## What are the genres of the most played games (hours played) on the PS4 for the first quarter of 2021?

# %% [markdown]
# In this part of the notebook, we try to find the genres of the 100 most played games on the PS4 for the first quarter of 2021.

# %%
for index, row in df_ps4_combined_sales.iterrows():
    if row['Tags'][0] != np.nan:
        print(row['Tags'][0])
# Out:
# Action
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-77865e7d02ba> in <module>
#       1 for index, row in df_ps4_combined_sales.iterrows():
# ----> 2     if row['Tags'][0] != np.nan:
#       3         print(row['Tags'][0])
#
# TypeError: 'float' object is not subscriptable

# %%
df_most_played['Genre'] = df_ps4_combined_sales['Tags']
# Out:
# <ipython-input-31-bdd45d488a41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_most_played['Genre'] = df_ps4_combined_sales['Tags']

# %%
# This is for Niko/Martin
#df_most_played.select(col("Tags").getItem(0))
#df.select(col("results.address_components.short_name").getItem(0))

# %%
df_most_played
# Out:
#     Hours_Played                             Title  \
# 51  93548.333333                          fortnite
# 14  84386.000000   call of duty black ops cold war
# 16  80789.333333       call of duty modern warfare
# 0   79539.000000                      apex legends
# 56  78739.333333                grand theft auto v
# ..           ...                               ...
# 37   3211.666667  efootball pes 2021 season update
# 65   3190.666667                     madden nfl 21
# 89   3151.000000           rise of the tomb raider
# 80   3103.500000                  outriders - demo
# 83   3079.000000                         persona 5
#
#                                                 Genre
# 51  [Action, zombie, sandbox, survival, co-op, MMO...
# 14                                                NaN
# 16  [Action, FPP, modern conflicts, FPS, network, ...
# 0   [Action, FPP, science fiction, play for free, ...
# 56  [Action, FPP, TPP, vehicles, Gangster, sandbox...
# ..                                                ...
# 37                                                NaN
# 65                                                NaN
# 89                                                NaN
# 80                                                NaN
# 83  [RPG, TPP, fantasy, turn-based, jRPG, PlayStat...
#
# [100 rows x 3 columns]

# %% [markdown]
# ## What are the ratings of the most played games (hours played) on the PS4 for the first quarter of 2021?

# %% [markdown]
# We first drop the Genre column.

# %%
df_most_played = df_most_played.drop(['Genre'], axis=1)

# %% [markdown]
# Add the Current Rating Column.

# %%
df_most_played['Current_Rating'] = df_ps4_combined_sales['Current_Rating']
df_most_played
# Out:
#     Hours_Played                             Title  Current_Rating
# 51  93548.333333                          fortnite           1.900
# 14  84386.000000   call of duty black ops cold war             NaN
# 16  80789.333333       call of duty modern warfare           7.645
# 0   79539.000000                      apex legends             NaN
# 56  78739.333333                grand theft auto v           8.950
# ..           ...                               ...             ...
# 37   3211.666667  efootball pes 2021 season update             NaN
# 65   3190.666667                     madden nfl 21             NaN
# 89   3151.000000           rise of the tomb raider             NaN
# 80   3103.500000                  outriders - demo             NaN
# 83   3079.000000                         persona 5           8.780
#
# [100 rows x 3 columns]

# %% [markdown]
# We drop the NaN values.

# %%
df_most_played.dropna()
# Out:
#     Hours_Played                                 Title  Current_Rating
# 51  93548.333333                              fortnite           1.900
# 16  80789.333333           call of duty modern warfare           7.645
# 56  78739.333333                    grand theft auto v           8.950
# 46  77593.000000                               fifa 21           5.215
# 90  63980.666667                         rocket league           6.800
# ..           ...                                   ...             ...
# 3    3421.000000              assassin's creed origins           8.250
# 33   3305.500000                          doom eternal           7.050
# 6    3289.000000                         battlefield 1           8.330
# 4    3253.000000  assassin's creed the ezio collection           6.950
# 83   3079.000000                             persona 5           8.780
#
# [69 rows x 3 columns]

# %% [markdown]
# Partition the values in to x and y axis.

# %%
x_values = df_most_played['Title']
y_values = df_most_played['Current_Rating']

# %% [markdown]
# Plot the graph.

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = x_values
y = y_values
ax.bar(x,y)
plt.xlabel('Title')
plt.ylabel('Current Rating')
plt.title('Rating of Top 100 Most Played Games')
plt.show()

# %% [markdown]
# Based on the graph observed, the rating of a game is more or less unrelated to the number of players. The distribution of the graph is still based on popularity (meaning, the x-axis is arranged by popularity in decreasing order). From the graph, even the top 5 most played games have relatively lower ratings than some of the rest of the games that are less popular.

# %% [markdown]
# ## Are the most played games dominated by multiplayer or singleplayer?

# %%
df_ps4_combined_sales['Mode'].value_counts()
# Out:
# single / multiplayer          38
# single player                 34
# massive online multiplayer     5
# multiplayer                    5
# Multiplayer mode: Internet     1
# Name: Mode, dtype: int64

# %%
df_ps4_combined_sales['Mode'] = df_ps4_combined_sales['Mode'].map({'multiplayer': 'multiplayer', 'single player' : 'single player', 'single / multiplayer': 'single / multiplayer', 'massive online multiplayer': 'multiplayer', 'Multiplayer mode: Internet': 'multiplayer'})

# %%
df_ps4_combined_sales['Mode'].value_counts()
# Out:
# single / multiplayer    38
# single player           34
# multiplayer             11
# Name: Mode, dtype: int64

# %% [markdown]
# We drop the 'Current_Rating' Column.

# %%
df_most_played = df_most_played.drop(['Current_Rating'], axis=1)

# %% [markdown]
# We add the 'Mode' Column

# %%
df_most_played['Mode'] = df_ps4_combined_sales['Mode']

# %% [markdown]
# We drop the 'NaN' values.

# %%
df_most_played.dropna()
# Out:
#     Hours_Played                                 Title                  Mode
# 51  93548.333333                              fortnite  single / multiplayer
# 16  80789.333333           call of duty modern warfare  single / multiplayer
# 0   79539.000000                          apex legends           multiplayer
# 56  78739.333333                    grand theft auto v         single player
# 46  77593.000000                               fifa 21  single / multiplayer
# ..           ...                                   ...                   ...
# 3    3421.000000              assassin's creed origins         single player
# 33   3305.500000                          doom eternal  single / multiplayer
# 6    3289.000000                         battlefield 1  single / multiplayer
# 4    3253.000000  assassin's creed the ezio collection         single player
# 83   3079.000000                             persona 5         single player
#
# [70 rows x 3 columns]

# %%
df_most_played['Mode'].value_counts()
# Out:
# single / multiplayer    33
# single player           28
# multiplayer              9
# Name: Mode, dtype: int64

# %%
# Split the dataframe into their mode
single_player = df_most_played[df_most_played['Mode'] == 'single player']
multiplayer = df_most_played[df_most_played['Mode'] == 'multiplayer']
single_multi = df_most_played[df_most_played['Mode'] == 'single / multiplayer']

# Give x and y values
x_values = ['Single Player', 'Multiplayer', 'Single / Multiplayer']
y_values = [len(single_player.index), len(multiplayer.index), len(single_multi.index)]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = x_values
y = y_values
ax.bar(x,y)
plt.xlabel('Game Mode')
plt.ylabel('Number of Games')
plt.title('Number of Games per Game Mode')
plt.show()

# %% [markdown]
# ## What is the revenue of the most played games (hours played) on the PS4 for the first quarter of 2021 based on singleplayer or multiplayer?

# %%
df_ps4_times_sales = df_ps4_combined_sales
df_ps4_times_sales = df_ps4_times_sales.drop(['Tags'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Game_Description'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Release_Date_Day'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Publisher_x'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Total_Shipped'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Current_Rating'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Hours_Played'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Players'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Sessions'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Avg_Session_Seconds'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Count'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Developer'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Release_Date_Month'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Release_Date_Year'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Expected_Rating'], axis=1)
df_ps4_times_sales = df_ps4_times_sales.drop(['Publisher_y'], axis=1)

# %%
df_ps4_times_sales = df_ps4_times_sales.dropna()

# %%
df_ps4_times_sales
# Out:
#                                      Title                  Mode Total_Sales  \
# 56                      grand theft auto v         single player      19.39m
# 71                               minecraft  single / multiplayer       6.33m
# 29                               destiny 2  single / multiplayer       4.14m
# 26                        dead by daylight           multiplayer       0.22m
# 94               shadow of the tomb raider         single player       1.74m
# 2                 assassin's creed odyssey         single player       3.18m
# 50                               for honor  single / multiplayer       1.75m
# 102                             the crew 2           multiplayer       0.82m
# 41                               fallout 4         single player       8.48m
# 23                   dark souls remastered  single / multiplayer       0.49m
# 79                            no man's sky  single / multiplayer       2.26m
# 58                                hitman 2  single / multiplayer       0.51m
# 64                            just cause 4         single player       0.56m
# 3                 assassin's creed origins         single player       4.06m
# 6                            battlefield 1  single / multiplayer       7.26m
# 4     assassin's creed the ezio collection         single player       0.79m
# 83                               persona 5         single player       1.64m
# 77                  need for speed payback  single / multiplayer       2.18m
# 43                               far cry 5  single / multiplayer       3.95m
# 7                            battlefield 4  single / multiplayer       3.94m
# 107                             the sims 4         single player       1.39m
# 70              middle-earth shadow of war         single player       2.04m
# 49                        final fantasy xv         single player       5.07m
# 113  uncharted the nathan drake collection         single player       5.70m
# 36                         ea sports ufc 3  single / multiplayer       0.97m
#
#     NA_Sales PAL_Sales Japan_Sales Other_Sales
# 56     6.06m     9.71m       0.60m       3.02m
# 71     1.89m     3.13m       0.35m       0.96m
# 29     1.92m     1.44m       0.10m       0.69m
# 26     0.11m     0.06m       0.02m       0.04m
# 94     0.59m     0.82m       0.06m       0.27m
# 2      1.18m     1.40m       0.09m       0.51m
# 50     0.73m     0.66m       0.07m       0.28m
# 102    0.22m     0.42m       0.05m       0.12m
# 41     2.91m     3.97m       0.27m       1.34m
# 23     0.13m     0.16m       0.14m       0.06m
# 79     0.89m     0.97m       0.04m       0.37m
# 58     0.19m     0.22m       0.02m       0.08m
# 64     0.18m     0.26m       0.03m       0.09m
# 3      1.22m     2.11m       0.11m       0.63m
# 6      2.20m     3.65m       0.29m       1.12m
# 4      0.14m     0.52m       0.02m       0.12m
# 83     0.62m     0.34m       0.48m       0.20m
# 77     0.62m     1.18m       0.04m       0.34m
# 43     1.44m     1.73m       0.15m       0.62m
# 7      1.40m     1.74m       0.19m       0.62m
# 107    0.44m     0.72m       0.01m       0.22m
# 70     0.82m     0.84m       0.06m       0.33m
# 49     1.81m     1.53m       1.05m       0.68m
# 113    2.55m     2.11m       0.10m       0.94m
# 36     0.40m     0.41m       0.01m       0.16m

# %%
df_ps4_times_sales['Mode'] = df_ps4_times_sales['Mode'].map({'multiplayer': 'multiplayer', 'single player' : 'single player', 'single / multiplayer': 'single / multiplayer', 'massive online multiplayer': 'multiplayer', 'Multiplayer mode: Internet': 'multiplayer'})

# %%
df_ps4_times_sales = df_ps4_times_sales.reset_index(drop=True)
df_ps4_times_sales
# Out:
#                                     Title                  Mode Total_Sales  \
# 0                      grand theft auto v         single player      19.39m
# 1                               minecraft  single / multiplayer       6.33m
# 2                               destiny 2  single / multiplayer       4.14m
# 3                        dead by daylight           multiplayer       0.22m
# 4               shadow of the tomb raider         single player       1.74m
# 5                assassin's creed odyssey         single player       3.18m
# 6                               for honor  single / multiplayer       1.75m
# 7                              the crew 2           multiplayer       0.82m
# 8                               fallout 4         single player       8.48m
# 9                   dark souls remastered  single / multiplayer       0.49m
# 10                           no man's sky  single / multiplayer       2.26m
# 11                               hitman 2  single / multiplayer       0.51m
# 12                           just cause 4         single player       0.56m
# 13               assassin's creed origins         single player       4.06m
# 14                          battlefield 1  single / multiplayer       7.26m
# 15   assassin's creed the ezio collection         single player       0.79m
# 16                              persona 5         single player       1.64m
# 17                 need for speed payback  single / multiplayer       2.18m
# 18                              far cry 5  single / multiplayer       3.95m
# 19                          battlefield 4  single / multiplayer       3.94m
# 20                             the sims 4         single player       1.39m
# 21             middle-earth shadow of war         single player       2.04m
# 22                       final fantasy xv         single player       5.07m
# 23  uncharted the nathan drake collection         single player       5.70m
# 24                        ea sports ufc 3  single / multiplayer       0.97m
#
#    NA_Sales PAL_Sales Japan_Sales Other_Sales
# 0     6.06m     9.71m       0.60m       3.02m
# 1     1.89m     3.13m       0.35m       0.96m
# 2     1.92m     1.44m       0.10m       0.69m
# 3     0.11m     0.06m       0.02m       0.04m
# 4     0.59m     0.82m       0.06m       0.27m
# 5     1.18m     1.40m       0.09m       0.51m
# 6     0.73m     0.66m       0.07m       0.28m
# 7     0.22m     0.42m       0.05m       0.12m
# 8     2.91m     3.97m       0.27m       1.34m
# 9     0.13m     0.16m       0.14m       0.06m
# 10    0.89m     0.97m       0.04m       0.37m
# 11    0.19m     0.22m       0.02m       0.08m
# 12    0.18m     0.26m       0.03m       0.09m
# 13    1.22m     2.11m       0.11m       0.63m
# 14    2.20m     3.65m       0.29m       1.12m
# 15    0.14m     0.52m       0.02m       0.12m
# 16    0.62m     0.34m       0.48m       0.20m
# 17    0.62m     1.18m       0.04m       0.34m
# 18    1.44m     1.73m       0.15m       0.62m
# 19    1.40m     1.74m       0.19m       0.62m
# 20    0.44m     0.72m       0.01m       0.22m
# 21    0.82m     0.84m       0.06m       0.33m
# 22    1.81m     1.53m       1.05m       0.68m
# 23    2.55m     2.11m       0.10m       0.94m
# 24    0.40m     0.41m       0.01m       0.16m

# %%
df_ps4_times_sales
# Out:
#                                     Title                  Mode Total_Sales  \
# 0                      grand theft auto v         single player      19.39m
# 1                               minecraft  single / multiplayer       6.33m
# 2                               destiny 2  single / multiplayer       4.14m
# 3                        dead by daylight           multiplayer       0.22m
# 4               shadow of the tomb raider         single player       1.74m
# 5                assassin's creed odyssey         single player       3.18m
# 6                               for honor  single / multiplayer       1.75m
# 7                              the crew 2           multiplayer       0.82m
# 8                               fallout 4         single player       8.48m
# 9                   dark souls remastered  single / multiplayer       0.49m
# 10                           no man's sky  single / multiplayer       2.26m
# 11                               hitman 2  single / multiplayer       0.51m
# 12                           just cause 4         single player       0.56m
# 13               assassin's creed origins         single player       4.06m
# 14                          battlefield 1  single / multiplayer       7.26m
# 15   assassin's creed the ezio collection         single player       0.79m
# 16                              persona 5         single player       1.64m
# 17                 need for speed payback  single / multiplayer       2.18m
# 18                              far cry 5  single / multiplayer       3.95m
# 19                          battlefield 4  single / multiplayer       3.94m
# 20                             the sims 4         single player       1.39m
# 21             middle-earth shadow of war         single player       2.04m
# 22                       final fantasy xv         single player       5.07m
# 23  uncharted the nathan drake collection         single player       5.70m
# 24                        ea sports ufc 3  single / multiplayer       0.97m
#
#    NA_Sales PAL_Sales Japan_Sales Other_Sales
# 0     6.06m     9.71m       0.60m       3.02m
# 1     1.89m     3.13m       0.35m       0.96m
# 2     1.92m     1.44m       0.10m       0.69m
# 3     0.11m     0.06m       0.02m       0.04m
# 4     0.59m     0.82m       0.06m       0.27m
# 5     1.18m     1.40m       0.09m       0.51m
# 6     0.73m     0.66m       0.07m       0.28m
# 7     0.22m     0.42m       0.05m       0.12m
# 8     2.91m     3.97m       0.27m       1.34m
# 9     0.13m     0.16m       0.14m       0.06m
# 10    0.89m     0.97m       0.04m       0.37m
# 11    0.19m     0.22m       0.02m       0.08m
# 12    0.18m     0.26m       0.03m       0.09m
# 13    1.22m     2.11m       0.11m       0.63m
# 14    2.20m     3.65m       0.29m       1.12m
# 15    0.14m     0.52m       0.02m       0.12m
# 16    0.62m     0.34m       0.48m       0.20m
# 17    0.62m     1.18m       0.04m       0.34m
# 18    1.44m     1.73m       0.15m       0.62m
# 19    1.40m     1.74m       0.19m       0.62m
# 20    0.44m     0.72m       0.01m       0.22m
# 21    0.82m     0.84m       0.06m       0.33m
# 22    1.81m     1.53m       1.05m       0.68m
# 23    2.55m     2.11m       0.10m       0.94m
# 24    0.40m     0.41m       0.01m       0.16m

# %%
df_ps4_times_sales['Total_Sales'][1]
# Out:
# '6.33m'

# %%
Total_sales_cleaned = []
NA_sales_cleaned = []
PAL_sales_cleaned = []
Japan_sales_cleaned = []
Other_sales_cleaned = []
for index, row in df_ps4_times_sales.iterrows():
    row['Total_Sales'] = row['Total_Sales'].replace('m','')
    row['NA_Sales'] = row['NA_Sales'].replace('m','')
    row['PAL_Sales'] = row['PAL_Sales'].replace('m','')
    row['Japan_Sales'] = row['Japan_Sales'].replace('m','')
    row['Other_Sales'] = row['Other_Sales'].replace('m','')
    #print(row['Title'])
    Total_sales_cleaned.append(float(row['Total_Sales']))
    NA_sales_cleaned.append(float(row['NA_Sales']))
    PAL_sales_cleaned.append(float(row['PAL_Sales']))
    Japan_sales_cleaned.append(float(row['Japan_Sales']))
    Other_sales_cleaned.append(float(row['Other_Sales']))
    
df_ps4_times_sales['Total_Sales'] = Total_sales_cleaned
df_ps4_times_sales['NA_Sales'] = NA_sales_cleaned
df_ps4_times_sales['PAL_Sales'] = PAL_sales_cleaned
df_ps4_times_sales['Japan_Sales'] = Japan_sales_cleaned
df_ps4_times_sales['Other_Sales'] = Other_sales_cleaned

# %%
df_ps4_times_sales
# Out:
#                                     Title                  Mode  Total_Sales  \
# 0                      grand theft auto v         single player        19.39
# 1                               minecraft  single / multiplayer         6.33
# 2                               destiny 2  single / multiplayer         4.14
# 3                        dead by daylight           multiplayer         0.22
# 4               shadow of the tomb raider         single player         1.74
# 5                assassin's creed odyssey         single player         3.18
# 6                               for honor  single / multiplayer         1.75
# 7                              the crew 2           multiplayer         0.82
# 8                               fallout 4         single player         8.48
# 9                   dark souls remastered  single / multiplayer         0.49
# 10                           no man's sky  single / multiplayer         2.26
# 11                               hitman 2  single / multiplayer         0.51
# 12                           just cause 4         single player         0.56
# 13               assassin's creed origins         single player         4.06
# 14                          battlefield 1  single / multiplayer         7.26
# 15   assassin's creed the ezio collection         single player         0.79
# 16                              persona 5         single player         1.64
# 17                 need for speed payback  single / multiplayer         2.18
# 18                              far cry 5  single / multiplayer         3.95
# 19                          battlefield 4  single / multiplayer         3.94
# 20                             the sims 4         single player         1.39
# 21             middle-earth shadow of war         single player         2.04
# 22                       final fantasy xv         single player         5.07
# 23  uncharted the nathan drake collection         single player         5.70
# 24                        ea sports ufc 3  single / multiplayer         0.97
#
#     NA_Sales  PAL_Sales  Japan_Sales  Other_Sales
# 0       6.06       9.71         0.60         3.02
# 1       1.89       3.13         0.35         0.96
# 2       1.92       1.44         0.10         0.69
# 3       0.11       0.06         0.02         0.04
# 4       0.59       0.82         0.06         0.27
# 5       1.18       1.40         0.09         0.51
# 6       0.73       0.66         0.07         0.28
# 7       0.22       0.42         0.05         0.12
# 8       2.91       3.97         0.27         1.34
# 9       0.13       0.16         0.14         0.06
# 10      0.89       0.97         0.04         0.37
# 11      0.19       0.22         0.02         0.08
# 12      0.18       0.26         0.03         0.09
# 13      1.22       2.11         0.11         0.63
# 14      2.20       3.65         0.29         1.12
# 15      0.14       0.52         0.02         0.12
# 16      0.62       0.34         0.48         0.20
# 17      0.62       1.18         0.04         0.34
# 18      1.44       1.73         0.15         0.62
# 19      1.40       1.74         0.19         0.62
# 20      0.44       0.72         0.01         0.22
# 21      0.82       0.84         0.06         0.33
# 22      1.81       1.53         1.05         0.68
# 23      2.55       2.11         0.10         0.94
# 24      0.40       0.41         0.01         0.16

# %%
df_ps4_times_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        25 non-null     object
#  1   Mode         25 non-null     object
#  2   Total_Sales  25 non-null     float64
#  3   NA_Sales     25 non-null     float64
#  4   PAL_Sales    25 non-null     float64
#  5   Japan_Sales  25 non-null     float64
#  6   Other_Sales  25 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 1.5+ KB

# %%
df_ps4_times_sales_agg = df_ps4_times_sales.groupby('Mode').agg(
    Total_Sales = ('Total_Sales', 'mean'),
    NA_Sales = ('NA_Sales', 'mean'),
    PAL_Sales = ('PAL_Sales', 'mean'),
    Japan_Sales = ('Japan_Sales', 'mean'),
    Other_Sales = ('Other_Sales', 'mean'),
)

# %%
df_ps4_times_sales_agg
# Out:
#                       Total_Sales  NA_Sales  PAL_Sales  Japan_Sales  \
# Mode
# multiplayer              0.520000  0.165000     0.2400     0.035000
# single / multiplayer     3.070909  1.073636     1.3900     0.127273
# single player            4.503333  1.543333     2.0275     0.240000
#
#                       Other_Sales
# Mode
# multiplayer              0.080000
# single / multiplayer     0.481818
# single player            0.695833

# %%
import numpy as np
import matplotlib.pyplot as plt
Label = ['Multiplayer', 'Single/Multiplayer', 'Singlerplayer']
fig = plt.figure()
X = np.arange(len(Label))
ax = fig.add_axes([0,0,1,1])
ax.bar(X - 0.20,df_ps4_times_sales_agg['Total_Sales'], color = 'b', width = 0.10,label = 'Total_Sales')
ax.bar(X - 0.10,df_ps4_times_sales_agg['NA_Sales'], color = 'g', width = 0.10,label = 'NA_Sales')
ax.bar(X + 0.00,df_ps4_times_sales_agg['PAL_Sales'], color = 'r', width = 0.10,label = 'PAL_Sales')
ax.bar(X + 0.10,df_ps4_times_sales_agg['Japan_Sales'], color = 'y', width = 0.10,label = 'Japan_Sales')
ax.bar(X + 0.20,df_ps4_times_sales_agg['Other_Sales'], color = 'black', width = 0.10,label = 'Other_Sales')
plt.xticks(X, Label)
plt.xlabel("Game Mode")
plt.ylabel("Sales (in millions)")
plt.title("Average Sales per Game Mode")
plt.legend()
plt.show()

# %% [markdown]
# # What are the genres of the most played games (hours played) on the PS4 for the first quarter of 2021?

# %% [markdown]
# First, We Clean thee data and retain only the Necessary features, while also dropping rows with NaN

# %%
df_s4_Genre = df_ps4_combined['Tags']

# %%
df_s4_Genre
# Out:
# 0      [Action, FPP, science fiction, play for free, ...
# 1      [Action, FPP, dinosaurs, sandbox, RPG elements...
# 2      [RPG, TPP, Stealth, sandbox, Ancient history, ...
# 3      [Action, TPP, science fiction, Stealth, sandbo...
# 4      [Action, TPP, science fiction, Stealth, packag...
#                              ...
# 117    [Action, TPP, science fiction, play for free, ...
# 118    [Action, TPP, cyberpunk, science fiction, Stea...
# 119                                                  NaN
# 120                                                  NaN
# 121    [RPG, TPP, turn-based, Gangster, Japan, jRPG, ...
# Name: Tags, Length: 122, dtype: object

# %%
Genres = []
for row in df_s4_Genre.dropna():
    Genres = Genres + row
    
Genres
# Out:
# ['Action',
#  'FPP',
#  'science fiction',
#  'play for free',
#  'FPS',
#  'network',
#  'co-op',
#  'shooters',
#  'Battle Royale',
#  'Games as a service',
#  'Action',
#  'FPP',
#  'dinosaurs',
#  'sandbox',
#  'RPG elements',
#  'survival',
#  'indie games',
#  'co-op',
#  'MMO',
#  'crafting',
#  'RPG',
#  'TPP',
#  'Stealth',
#  'sandbox',
#  'Ancient history',
#  'ships',
#  'historical',
#  'action adventure',
#  'action RPG',
#  'slasher',
#  'Ancient Greece',
#  'Action',
#  'TPP',
#  'science fiction',
#  'Stealth',
#  'sandbox',
#  'Ancient history',
#  'historical',
#  'Egypt',
#  'action adventure',
#  'Action',
#  'TPP',
#  'science fiction',
#  'Stealth',
#  'package',
#  'reeditions/remasters/remakes',
#  'Renaissance',
#  'historical',
#  'RPG',
#  'TPP',
#  'Stealth',
#  'the middle ages',
#  'sandbox',
#  'the Vikings',
#  'action adventure',
#  'action RPG',
#  'Find Your Next Game',
#  'Action',
#  'FPP',
#  'World War I',
#  'FPS',
#  'co-op',
#  'shooters',
#  'early 20th century',
#  'EA Play',
#  'Action',
#  'FPP',
#  'modern conflicts',
#  'FPS',
#  'co-op',
#  'shooters',
#  'EA Play',
#  'Action',
#  'FPP',
#  'World War II',
#  'FPS',
#  'war',
#  'co-op',
#  'shooters',
#  'Battle Royale',
#  'EA Play',
#  'RPG',
#  'TPP',
#  'fantasy',
#  'horror',
#  'co-op',
#  'action RPG',
#  'soulslike',
#  'PlayStation exclusive titles',
#  'Action',
#  'FPP',
#  'science fiction',
#  'FPS',
#  'humorous',
#  'for 2 people',
#  'co-op',
#  'shooters',
#  'splitscreen',
#  'Role-playing shooter',
#  'Action',
#  'FPP',
#  'modern conflicts',
#  'FPS',
#  'network',
#  'cross-platform',
#  'co-op',
#  'shooters',
#  'Action',
#  'FPP',
#  'World War II',
#  'FPS',
#  'co-op',
#  'shooters',
#  'Adventure',
#  'TPP',
#  '3D platformers',
#  'experimental/art',
#  'action adventure',
#  'PlayStation VR',
#  'virtual reality',
#  'PlayStation exclusive titles',
#  'Action',
#  'TPP',
#  'science fiction',
#  'TPS',
#  'shooters',
#  'action adventure',
#  'RPG',
#  'FPP',
#  'cyberpunk',
#  'science fiction',
#  'sandbox',
#  'Polish',
#  'action RPG',
#  'Find Your Next Game',
#  'RPG',
#  'TPP',
#  'fantasy',
#  'co-op',
#  'action RPG',
#  'soulslike',
#  'RPG',
#  'TPP',
#  'fantasy',
#  'reeditions/remasters/remakes',
#  'co-op',
#  'action RPG',
#  'soulslike',
#  'Action',
#  'TPP',
#  'zombie',
#  'Post Apocalypse',
#  'sandbox',
#  'TPS',
#  'shooters',
#  'action adventure',
#  'Find Your Next Game',
#  'Action',
#  'FPP',
#  'TPP',
#  'zombie',
#  'Post Apocalypse',
#  'sandbox',
#  'survival',
#  'MMO',
#  'crafting',
#  'Action',
#  'FPP',
#  'TPP',
#  'survival horror',
#  'Stealth',
#  'horror',
#  'network',
#  'co-op',
#  'Action',
#  'TPP',
#  'science fiction',
#  'Post Apocalypse',
#  'transport',
#  'experimental/art',
#  'action adventure',
#  'exploration games',
#  'Find Your Next Game',
#  'Action',
#  'FPP',
#  'science fiction',
#  'play for free',
#  'FPS',
#  'RPG elements',
#  'co-op',
#  'MMO',
#  'shooters',
#  'Role-playing shooter',
#  'Games as a service',
#  'Adventure',
#  'TPP',
#  'cyberpunk',
#  'science fiction',
#  'arcade elements',
#  'Action',
#  'FPP',
#  'science fiction',
#  'FPS',
#  'network',
#  'shooters',
#  'Fighting',
#  'science fiction',
#  'manga and anime',
#  'for 2 people',
#  'Dragon Ball',
#  '2.5 D',
#  'splitscreen',
#  'Sports',
#  'MMA',
#  'for 2 people',
#  'splitscreen',
#  'EA Play',
#  'Racing',
#  'Formula 1',
#  'vehicles',
#  'for 2 people',
#  'splitscreen',
#  'simulation elements',
#  'Find Your Next Game',
#  'Arcade',
#  'TPP',
#  'humorous',
#  'network',
#  'indie games',
#  'co-op',
#  'Battle Royale',
#  'Games as a service',
#  'RPG',
#  'FPP',
#  'TPP',
#  'science fiction',
#  'Post Apocalypse',
#  'sandbox',
#  'FPS',
#  'TPS',
#  'crafting',
#  'Role-playing shooter',
#  'RPG',
#  'FPP',
#  'TPP',
#  'Post Apocalypse',
#  'sandbox',
#  'co-op',
#  'MMO',
#  'crafting',
#  'Role-playing shooter',
#  'Games as a service',
#  'Action',
#  'FPP',
#  'sandbox',
#  'FPS',
#  'co-op',
#  'crafting',
#  'shooters',
#  'Simulation',
#  'Economic',
#  'farm',
#  'machines and equipment',
#  'Sports',
#  'Football',
#  'for 2 people',
#  'splitscreen',
#  'EA Play',
#  'Sports',
#  'Football',
#  'for 2 people',
#  'splitscreen',
#  'Find Your Next Game',
#  'EA Play',
#  'RPG',
#  'TPP',
#  'fantasy',
#  'science fiction',
#  'reeditions/remasters/remakes',
#  'action RPG',
#  'jRPG',
#  'PlayStation exclusive titles',
#  'urban fantasy',
#  'RPG',
#  'TPP',
#  'fantasy',
#  'science fiction',
#  'sandbox',
#  'action RPG',
#  'jRPG',
#  'Action',
#  'TPP',
#  'the middle ages',
#  'co-op',
#  'alternative history',
#  'Action',
#  'zombie',
#  'sandbox',
#  'survival',
#  'co-op',
#  'MMO',
#  'crafting',
#  'RPG',
#  'TPP',
#  'fantasy',
#  "hack'and'slash",
#  'play for free',
#  'sandbox',
#  'co-op',
#  'action RPG',
#  'jRPG',
#  'Games as a service',
#  'Action',
#  'TPP',
#  'Stealth',
#  'sandbox',
#  'historical',
#  'Japan',
#  'Samurai',
#  'action adventure',
#  'PlayStation exclusive titles',
#  'Find Your Next Game',
#  'Action',
#  'TPP',
#  'RPG elements',
#  'Norse mythology',
#  'action adventure',
#  'slasher',
#  'PlayStation exclusive titles',
#  'Action',
#  'FPP',
#  'TPP',
#  'vehicles',
#  'Gangster',
#  'sandbox',
#  'FPS',
#  'TPS',
#  'reeditions/remasters/remakes',
#  'shooters',
#  'RPG',
#  'TPP',
#  'fantasy',
#  'action RPG',
#  'XVII century',
#  'Action',
#  'TPP',
#  'Stealth',
#  'TPS',
#  'co-op',
#  'shooters',
#  'Action',
#  'TPP',
#  'Stealth',
#  'TPS',
#  'shooters',
#  'PlayStation VR',
#  'virtual reality',
#  'Find Your Next Game',
#  'Action',
#  'TPP',
#  'science fiction',
#  'Post Apocalypse',
#  'sandbox',
#  'RPG elements',
#  'action adventure',
#  'action RPG',
#  'Find Your Next Game',
#  'Action',
#  'TPP',
#  'sandbox',
#  'TPS',
#  'shooters',
#  'Action',
#  'TPP',
#  'science fiction',
#  'comics',
#  'superheroes',
#  "beat 'em up",
#  'co-op',
#  'Marvel Comics',
#  'Find Your Next Game',
#  'Games as a service',
#  'Action',
#  'TPP',
#  'fantasy',
#  "hack'and'slash",
#  'sandbox',
#  'The Lord Of The Rings',
#  'action adventure',
#  'Adventure',
#  'FPP',
#  'TPP',
#  'fantasy',
#  'sandbox',
#  'RPG elements',
#  'survival',
#  'co-op',
#  'crafting',
#  'action adventure',
#  'Fighting',
#  'for 2 people',
#  '2.5 D',
#  'splitscreen',
#  'urban fantasy',
#  'Sports',
#  'Basketball',
#  'for 2 people',
#  'NBA',
#  'splitscreen',
#  'Find Your Next Game',
#  'Racing',
#  'vehicles',
#  'cross-platform',
#  'EA Play',
#  'Racing',
#  'vehicles',
#  'co-op',
#  'EA Play',
#  'RPG',
#  'TPP',
#  'fantasy',
#  'co-op',
#  'Japanese mythology',
#  'Japan',
#  'action RPG',
#  'soulslike',
#  'Find Your Next Game',
#  'Action',
#  'FPP',
#  'TPP',
#  'science fiction',
#  'sandbox',
#  'Cosmic',
#  'indie games',
#  'co-op',
#  'space ships',
#  'crafting',
#  'action adventure',
#  'exploration games',
#  'RPG',
#  'TPP',
#  'fantasy',
#  'turn-based',
#  'jRPG',
#  'PlayStation exclusive titles',
#  'urban fantasy',
#  'RPG',
#  'TPP',
#  'turn-based',
#  'reeditions/remasters/remakes',
#  'jRPG',
#  'PlayStation exclusive titles',
#  'urban fantasy',
#  'Action',
#  'TPP',
#  'science fiction',
#  '3D platformers',
#  'humorous',
#  'action adventure',
#  'PlayStation exclusive titles',
#  'Action',
#  'FPP',
#  'TPP',
#  'sandbox',
#  'western',
#  'FPS',
#  'TPS',
#  'co-op',
#  'shooters',
#  'action adventure',
#  '19th century',
#  'Action',
#  'TPP',
#  'Post Apocalypse',
#  'RPG elements',
#  'TPS',
#  'co-op',
#  'shooters',
#  'Role-playing shooter',
#  'soulslike',
#  'urban fantasy',
#  'Arcade',
#  'science fiction',
#  'vehicles',
#  'play for free',
#  'network',
#  'for 2 people',
#  'cross-platform',
#  'co-op',
#  'splitscreen',
#  'Games as a service',
#  'Action',
#  'TPP',
#  'fantasy',
#  'Stealth',
#  'RPG elements',
#  'Japan',
#  'action adventure',
#  'soulslike',
#  'Action',
#  'TPP',
#  'logical elements',
#  'TPS',
#  'crafting',
#  'action adventure',
#  'Action',
#  'FPP',
#  'TPP',
#  'science fiction',
#  'Star Wars',
#  'FPS',
#  'Cosmic',
#  'videos',
#  'TPS',
#  'co-op',
#  'shooters',
#  'Games as a service',
#  'EA Play',
#  'Action',
#  'TPP',
#  'science fiction',
#  'Star Wars',
#  'action adventure',
#  'Find Your Next Game',
#  'EA Play',
#  'RPG',
#  'fantasy',
#  'sandbox',
#  'farm',
#  '2D',
#  'top-down',
#  'cross-platform',
#  'indie games',
#  'co-op',
#  'Adventure',
#  'FPP',
#  'science fiction',
#  'sandbox',
#  'RPG elements',
#  'survival',
#  'under water',
#  'crafting',
#  'action adventure',
#  'exploration games',
#  'Racing',
#  'vehicles',
#  'planes',
#  'sandbox',
#  'motorbike',
#  'co-op',
#  'MMO',
#  'boats',
#  'RPG',
#  'FPP',
#  'TPP',
#  'fantasy',
#  'PvP',
#  'PvE',
#  'MMORPG',
#  'The Elder Scrolls',
#  'MMO',
#  'Action',
#  'FPP',
#  'survival horror',
#  'sandbox',
#  'horror',
#  'survival',
#  'indie games',
#  'co-op',
#  'crafting',
#  'Action',
#  'TPP',
#  'Stealth',
#  'Post Apocalypse',
#  'TPS',
#  'crafting',
#  'shooters',
#  'action adventure',
#  'PlayStation exclusive titles',
#  'Find Your Next Game',
#  'Action',
#  'TPP',
#  'Post Apocalypse',
#  'horror',
#  'TPS',
#  'reeditions/remasters/remakes',
#  'co-op',
#  'crafting',
#  'shooters',
#  'action adventure',
#  'PlayStation exclusive titles',
#  'Simulation',
#  'Economic',
#  'sandbox',
#  'Isometric view',
#  'life Simulator',
#  'EA Play',
#  'RPG',
#  'TPP',
#  'fantasy',
#  'books',
#  'sandbox',
#  'Polish',
#  'action RPG',
#  'Action',
#  'TPP',
#  'RPG elements',
#  'TPS',
#  'co-op',
#  'MMO',
#  'shooters',
#  'Role-playing shooter',
#  'Games as a service',
#  'Action',
#  'TPP',
#  'package',
#  'TPS',
#  'reeditions/remasters/remakes',
#  'shooters',
#  'action adventure',
#  'PlayStation exclusive titles',
#  'Action',
#  'TPP',
#  'play for free',
#  'Post Apocalypse',
#  'network',
#  'TPS',
#  'co-op',
#  'alternative history',
#  'shooters',
#  '90s',
#  'Simulation',
#  'World War II',
#  'planes',
#  'play for free',
#  'network',
#  'MMO',
#  'Action',
#  'TPP',
#  'science fiction',
#  'play for free',
#  'RPG elements',
#  'TPS',
#  'co-op',
#  'MMO',
#  'shooters',
#  'Games as a service',
#  'Action',
#  'TPP',
#  'cyberpunk',
#  'science fiction',
#  'Stealth',
#  'sandbox',
#  'dystopia',
#  'co-op',
#  'Find Your Next Game',
#  'RPG',
#  'TPP',
#  'turn-based',
#  'Gangster',
#  'Japan',
#  'jRPG',
#  'Find Your Next Game']

# %%
from collections import Counter
c = Counter(Genres)
c
# Out:
# Counter({'Action': 45,
#          'FPP': 24,
#          'science fiction': 24,
#          'play for free': 7,
#          'FPS': 14,
#          'network': 8,
#          'co-op': 37,
#          'shooters': 25,
#          'Battle Royale': 3,
#          'Games as a service': 10,
#          'dinosaurs': 1,
#          'sandbox': 28,
#          'RPG elements': 10,
#          'survival': 6,
#          'indie games': 5,
#          'MMO': 10,
#          'crafting': 13,
#          'RPG': 19,
#          'TPP': 53,
#          'Stealth': 11,
#          'Ancient history': 2,
#          'ships': 1,
#          'historical': 4,
#          'action adventure': 22,
#          'action RPG': 13,
#          'slasher': 2,
#          'Ancient Greece': 1,
#          'Egypt': 1,
#          'package': 2,
#          'reeditions/remasters/remakes': 7,
#          'Renaissance': 1,
#          'the middle ages': 2,
#          'the Vikings': 1,
#          'Find Your Next Game': 16,
#          'World War I': 1,
#          'early 20th century': 1,
#          'EA Play': 11,
#          'modern conflicts': 2,
#          'World War II': 3,
#          'war': 1,
#          'fantasy': 15,
#          'horror': 4,
#          'soulslike': 6,
#          'PlayStation exclusive titles': 11,
#          'humorous': 3,
#          'for 2 people': 9,
#          'splitscreen': 9,
#          'Role-playing shooter': 6,
#          'cross-platform': 4,
#          'Adventure': 4,
#          '3D platformers': 2,
#          'experimental/art': 2,
#          'PlayStation VR': 2,
#          'virtual reality': 2,
#          'TPS': 17,
#          'cyberpunk': 3,
#          'Polish': 2,
#          'zombie': 3,
#          'Post Apocalypse': 10,
#          'survival horror': 2,
#          'transport': 1,
#          'exploration games': 3,
#          'arcade elements': 1,
#          'Fighting': 2,
#          'manga and anime': 1,
#          'Dragon Ball': 1,
#          '2.5 D': 2,
#          'Sports': 4,
#          'MMA': 1,
#          'Racing': 4,
#          'Formula 1': 1,
#          'vehicles': 6,
#          'simulation elements': 1,
#          'Arcade': 2,
#          'Simulation': 3,
#          'Economic': 2,
#          'farm': 2,
#          'machines and equipment': 1,
#          'Football': 2,
#          'jRPG': 6,
#          'urban fantasy': 5,
#          'alternative history': 2,
#          "hack'and'slash": 2,
#          'Japan': 4,
#          'Samurai': 1,
#          'Norse mythology': 1,
#          'Gangster': 2,
#          'XVII century': 1,
#          'comics': 1,
#          'superheroes': 1,
#          "beat 'em up": 1,
#          'Marvel Comics': 1,
#          'The Lord Of The Rings': 1,
#          'Basketball': 1,
#          'NBA': 1,
#          'Japanese mythology': 1,
#          'Cosmic': 2,
#          'space ships': 1,
#          'turn-based': 3,
#          'western': 1,
#          '19th century': 1,
#          'logical elements': 1,
#          'Star Wars': 2,
#          'videos': 1,
#          '2D': 1,
#          'top-down': 1,
#          'under water': 1,
#          'planes': 2,
#          'motorbike': 1,
#          'boats': 1,
#          'PvP': 1,
#          'PvE': 1,
#          'MMORPG': 1,
#          'The Elder Scrolls': 1,
#          'Isometric view': 1,
#          'life Simulator': 1,
#          'books': 1,
#          '90s': 1,
#          'dystopia': 1})

# %%
Genres_df = pd.DataFrame.from_dict(c, orient='index').sort_values(by=[0], ascending = False).reset_index()
Genres_df.columns=['Genre','Count']
Genres_df
# Out:
#                      Genre  Count
# 0                      TPP     53
# 1                   Action     45
# 2                    co-op     37
# 3                  sandbox     28
# 4                 shooters     25
# ..                     ...    ...
# 114            superheroes      1
# 115              transport      1
# 116          Marvel Comics      1
# 117  The Lord Of The Rings      1
# 118               dystopia      1
#
# [119 rows x 2 columns]

# %% [markdown]
# ### Based on story and gameplay, what are the similarities between the most played games (hours played) on the PS4 for the first quarter of 2021?

# %%
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
text = " ".join(str(review) for review in df_ps4_combined.Game_Description)

# %%
#stopwords
stopwords = set(STOPWORDS)
stopwords.update(["game", "character", "player", 'players','mode', 'one','gameplay', 'developed', 'developer', 'â', 's', 'games', 
                  'play', 'developers', 'new', 'PS4', 'will'])

# %%
# Generate word cloud
wc = WordCloud(width = 3000, height = 2000, random_state=1, background_color='salmon', colormap='Pastel1', collocations=False, stopwords = stopwords).generate(text)
# Plot
plot_cloud(wc)

# %%
mask = np.array(Image.open('controller.png'))
wc = WordCloud(stopwords=stopwords,
               mask=mask, background_color="white",
               max_words=100, max_font_size=256,
               random_state=42, width=mask.shape[1],
               height=mask.shape[0])
wc.generate(text)
plt.figure(figsize=(50,50))
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
